# %% [markdown]
# # ”Nishika”より「中古マンションの価格予測タスク」コンペにて分析

# %%
# 再読み込み、バグのため際読み
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 簡易概要
# - 本コンペティションのテーマは国内の中古マンションの価格推定
# - 目的変数は、取引価格（総額）について常用対数をとった、「取引価格（総額）_log」
# - 予測精度の評価はMAE(予測値)
# $$
# \text{MAE} = \frac{1}{n} \sum_{i=1}^{n} |y_i - \hat{y}_i|
# $$

# %% [markdown]
# ## 探索的データ分析の実施

# %%
import glob #ファイルのパターン検索
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
files = glob.glob("/content/drive/MyDrive/データコンペ用/data/train/train/*.csv") #ファイルの一括読み込み

# %%
# csvファイルの読み込み
data_list = []
for file in files:
  data_list.append(pd.read_csv(file, index_col=0)) #index_col=0で0列目をインデックス
# Out:
# <ipython-input-12-b6f9fed9de7f>:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_list.append(pd.read_csv(file, index_col=0)) #index_col=0で0列目をインデックス
# <ipython-input-12-b6f9fed9de7f>:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_list.append(pd.read_csv(file, index_col=0)) #index_col=0で0列目をインデックス

# %%
data_list
# Out:
# [                種類  地域  市区町村コード 都道府県名    市区町村名   地区名  最寄駅：名称 最寄駅：距離（分）   間取り  \
#  ID
#  23167208  中古マンション等 NaN    23222   愛知県      東海市  加木屋町    八幡新田         4  ３ＬＤＫ
#  23071718  中古マンション等 NaN    23226   愛知県     尾張旭市   井田町  三郷(愛知)        13  ３ＬＤＫ
#  23197007  中古マンション等 NaN    23116   愛知県  名古屋市天白区    中平   原(愛知)        22  ４ＬＤＫ
#  23132701  中古マンション等 NaN    23211   愛知県      豊田市  日之出町     豊田市        11  ４ＬＤＫ
#  23002332  中古マンション等 NaN    23102   愛知県   名古屋市東区     泉      高岳         5    １Ｋ
#  ...            ...  ..      ...   ...      ...   ...     ...       ...   ...
#  23089122  中古マンション等 NaN    23102   愛知県   名古屋市東区   砂田橋     砂田橋         8  ３ＬＤＫ
#  23116033  中古マンション等 NaN    23109   愛知県  名古屋市熱田区    沢上  金山(愛知)         6  ３ＬＤＫ
#  23053675  中古マンション等 NaN    23211   愛知県      豊田市   下林町     上挙母        12  ４ＬＤＫ
#  23064697  中古マンション等 NaN    23219   愛知県      小牧市    中央      小牧         6  ３ＬＤＫ
#  23008406  中古マンション等 NaN    23106   愛知県   名古屋市中区    大須    大須観音         1    １Ｋ
#
# ...

# %%
# 読み込んだcsvファイルの縦結合
df = pd.concat(data_list) #axis = 0 が縦、axsis = 1 が横
df
# Out:
#                 種類  地域  市区町村コード 都道府県名    市区町村名      地区名  最寄駅：名称 最寄駅：距離（分）  \
# ID
# 23167208  中古マンション等 NaN    23222   愛知県      東海市     加木屋町    八幡新田         4
# 23071718  中古マンション等 NaN    23226   愛知県     尾張旭市      井田町  三郷(愛知)        13
# 23197007  中古マンション等 NaN    23116   愛知県  名古屋市天白区       中平   原(愛知)        22
# 23132701  中古マンション等 NaN    23211   愛知県      豊田市     日之出町     豊田市        11
# 23002332  中古マンション等 NaN    23102   愛知県   名古屋市東区        泉      高岳         5
# ...            ...  ..      ...   ...      ...      ...     ...       ...
# 24028351  中古マンション等 NaN    24202   三重県     四日市市       芝田     中川原         4
# 24040531  中古マンション等 NaN    24201   三重県       津市  一身田上津部田       津        16
# 24056543  中古マンション等 NaN    24205   三重県      桑名市      明正町      益生         4
# 24013277  中古マンション等 NaN    24205   三重県      桑名市      中央町      桑名        14
# 24015318  中古マンション等 NaN    24207   三重県      鈴鹿市      白子町      白子        24
#
# ...

# %%
df.info()
# 0 non-null つまりすべてのデータがNULlのカラムを確認
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 637351 entries, 23167208 to 24015318
# Data columns (total 27 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   種類            637351 non-null  object
#  1   地域            0 non-null       float64
#  2   市区町村コード       637351 non-null  int64
#  3   都道府県名         637351 non-null  object
#  4   市区町村名         637351 non-null  object
#  5   地区名           637060 non-null  object
#  6   最寄駅：名称        634732 non-null  object
#  7   最寄駅：距離（分）     614306 non-null  object
#  8   間取り           615609 non-null  object
#  9   面積（㎡）         637351 non-null  object
#  10  土地の形状         0 non-null       float64
#  11  間口            0 non-null       float64
#  12  延床面積（㎡）       0 non-null       float64
#  13  建築年           619117 non-null  object
#  14  建物の構造         623423 non-null  object
#  15  用途            591214 non-null  object
#  16  今後の利用目的       275091 non-null  object
# ...

# %%
# nullを除外する
null_list = []
for col in df.columns:
  nonnull = df[col].count() #count()でnullは0と表示されるため
  if nonnull == 0:
    null_list.append(col)
print(null_list)
df = df.drop(null_list, axis = 1) # axsis=1で列から除外
# Out:
# ['地域', '土地の形状', '間口', '延床面積（㎡）', '前面道路：方位', '前面道路：種類', '前面道路：幅員（ｍ）']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 637351 entries, 23167208 to 24015318
# Data columns (total 20 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   種類            637351 non-null  object
#  1   市区町村コード       637351 non-null  int64
#  2   都道府県名         637351 non-null  object
#  3   市区町村名         637351 non-null  object
#  4   地区名           637060 non-null  object
#  5   最寄駅：名称        634732 non-null  object
#  6   最寄駅：距離（分）     614306 non-null  object
#  7   間取り           615609 non-null  object
#  8   面積（㎡）         637351 non-null  object
#  9   建築年           619117 non-null  object
#  10  建物の構造         623423 non-null  object
#  11  用途            591214 non-null  object
#  12  今後の利用目的       275091 non-null  object
#  13  都市計画          618786 non-null  object
#  14  建ぺい率（％）       614848 non-null  float64
#  15  容積率（％）        614848 non-null  float64
#  16  取引時点          637351 non-null  object
# ...

# %%
# 同じ意味合いのデータを除外する
df["市区町村コード"].value_counts()
# Out:
# 市区町村コード
# 13111    12269
# 13108    11591
# 13112    10747
# 13103    10580
# 13104    10055
#          ...
# 40213        1
# 40341        1
# 15108        1
# 40212        1
# 28226        1
# Name: count, Length: 618, dtype: int64

# %%
df["市区町村名"].value_counts()
# Out:
# 市区町村名
# 大田区       12269
# 江東区       11591
# 世田谷区      10747
# 港区        10580
# 新宿区       10055
#           ...
# 行橋市           1
# 粕屋郡宇美町        1
# 新潟市西蒲区        1
# 大川市           1
# 淡路市           1
# Name: count, Length: 618, dtype: int64

# %%
# 上記の結果、市区町村・市区町村コードが同じデータであることがわかる
# 市区町村コードだけ残します
df = df.drop("市区町村名", axis=1)

# %%
# テーブル定義確認
df.astype("str").describe()
# Out:
#               種類 市区町村コード   都道府県名     地区名  最寄駅：名称 最寄駅：距離（分）     間取り   面積（㎡）  \
# count     637351  637351  637351  637351  637351    637351  637351  637351
# unique         1     618      47   12047    3832        35      64     114
# top     中古マンション等   13111     東京都      本町     nan         6    ３ＬＤＫ      70
# freq      637351   12269  190524    5267    2619     50928  272449   83443
#
#            建築年   建物の構造      用途 今後の利用目的    都市計画 建ぺい率（％）  容積率（％）        取引時点  \
# count   637351  637351  637351  637351  637351  637351  637351      637351
# unique      77      13      23       5      17       7      18          58
# top       平成3年      ＲＣ      住宅     nan    商業地域    60.0   200.0  2014年第１四半期
# freq     21982  431050  583722  362260  172628  349347  293388       13561
#
#             改装  取引の事情等       取引価格（総額）_log
# count   637351  637351             637351
# unique       3      10                380
# top        未改装     nan  7.176091259055681
# freq    419268  619076              20996

# %%
# unique	が種類のカラムだけ一つしかvalueがないため削除。
# df["種類"].value_counts()

# %%
df
# Out:
#                 種類  市区町村コード 都道府県名      地区名  最寄駅：名称 最寄駅：距離（分）   間取り 面積（㎡）  \
# ID
# 23167208  中古マンション等    23222   愛知県     加木屋町    八幡新田         4  ３ＬＤＫ    75
# 23071718  中古マンション等    23226   愛知県      井田町  三郷(愛知)        13  ３ＬＤＫ    50
# 23197007  中古マンション等    23116   愛知県       中平   原(愛知)        22  ４ＬＤＫ   100
# 23132701  中古マンション等    23211   愛知県     日之出町     豊田市        11  ４ＬＤＫ    90
# 23002332  中古マンション等    23102   愛知県        泉      高岳         5    １Ｋ    30
# ...            ...      ...   ...      ...     ...       ...   ...   ...
# 24028351  中古マンション等    24202   三重県       芝田     中川原         4  ３ＬＤＫ    70
# 24040531  中古マンション等    24201   三重県  一身田上津部田       津        16  ４ＬＤＫ    85
# 24056543  中古マンション等    24205   三重県      明正町      益生         4  ３ＬＤＫ    70
# 24013277  中古マンション等    24205   三重県      中央町      桑名        14  ３ＬＤＫ    70
# 24015318  中古マンション等    24207   三重県      白子町      白子        24  ３ＬＤＫ    70
#
#             建築年 建物の構造  用途 今後の利用目的          都市計画  建ぺい率（％）  容積率（％）        取引時点  \
# ID
# ...

# %%
df.info()
# 最寄駅:距離(分)、面積等、object型になってしまっている
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 637351 entries, 23167208 to 24015318
# Data columns (total 19 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   種類            637351 non-null  object
#  1   市区町村コード       637351 non-null  int64
#  2   都道府県名         637351 non-null  object
#  3   地区名           637060 non-null  object
#  4   最寄駅：名称        634732 non-null  object
#  5   最寄駅：距離（分）     614306 non-null  object
#  6   間取り           615609 non-null  object
#  7   面積（㎡）         637351 non-null  object
#  8   建築年           619117 non-null  object
#  9   建物の構造         623423 non-null  object
#  10  用途            591214 non-null  object
#  11  今後の利用目的       275091 non-null  object
#  12  都市計画          618786 non-null  object
#  13  建ぺい率（％）       614848 non-null  float64
#  14  容積率（％）        614848 non-null  float64
#  15  取引時点          637351 non-null  object
#  16  改装            580431 non-null  object
# ...

# %%
df["最寄駅：距離（分）"].value_counts()
# Out:
# 最寄駅：距離（分）
# 6          50928
# 4          48883
# 5          45337
# 8          44277
# 3          42880
# 9          38379
# 7          32369
# 30分?60分    31999
# 10         31572
# 11         30625
# 2          27100
# 13         22934
# 1          19746
# 14         18759
# 15         18552
# 12         15068
# 16         14354
# 18         11651
# 19         10533
# 20          8910
# 21          7163
# 23          6663
# 25          6169
# 24          4884
# 28          4133
# 26          3996
# 0           3704
# 1H?1H30     3624
# 29          3587
# 17          2515
# 22          1082
# 2H?          826
# 1H30?2H      692
# 27           412
# Name: count, dtype: int64

# %%
# "最寄駅：距離（分）" の中の文字列を一括でfloat型にかえる
dis = {
    "30分?60分": 45,
    "1H?1H30": 75,
    "2H?": 120,
    "1H30?2H": 105
}

df["最寄駅：距離（分）"] = df["最寄駅：距離（分）"].replace(dis).astype(float)
df["最寄駅：距離（分）"].value_counts()
# Out:
# 最寄駅：距離（分）
# 6.0      50928
# 4.0      48883
# 5.0      45337
# 8.0      44277
# 3.0      42880
# 9.0      38379
# 7.0      32369
# 45.0     31999
# 10.0     31572
# 11.0     30625
# 2.0      27100
# 13.0     22934
# 1.0      19746
# 14.0     18759
# 15.0     18552
# 12.0     15068
# 16.0     14354
# 18.0     11651
# 19.0     10533
# 20.0      8910
# 21.0      7163
# 23.0      6663
# 25.0      6169
# 24.0      4884
# 28.0      4133
# 26.0      3996
# 0.0       3704
# 75.0      3624
# 29.0      3587
# 17.0      2515
# 22.0      1082
# 120.0      826
# 105.0      692
# 27.0       412
# Name: count, dtype: int64

# %%
pd.set_option("display.max_rows", 500) #表示領域を増やす
df["面積（㎡）"].value_counts()
# Out:
# 面積（㎡）
# 70         70301
# 65         65176
# 60         51968
# 75         47362
# 20         40770
# 55         39149
# 80         32482
# 50         27629
# 15         25113
# 85         19604
# 25         18841
# 45         17514
# 70         13142
# 65         13113
# 90         12485
# 40         12221
# 60         11289
# 20         11258
# 30          9880
# 35          9482
# 75          9282
# 95          9121
# 55          8035
# 80          7090
# 15          5740
# 25          5654
# 50          5448
# 85          4530
# 100         4501
# 45          3147
# 90          2889
# 40          2785
# 105         2594
# 30          2548
# 35          2174
# 95          1887
# 110         1625
# 115         1176
# 10          1003
# 100          925
# 120          806
# 105          581
# 125          562
# 130          405
# 110          394
# 10           310
# 115          308
# 135          300
# 145          215
# 140          203
# 120          193
# 125          162
# ...

# %%
df["面積（㎡）"] = df["面積（㎡）"].replace("2000㎡以上", 2000).astype(float)

# %%
df["面積（㎡）"].value_counts()
# Out:
# 面積（㎡）
# 70.0      83443
# 65.0      78289
# 60.0      63257
# 75.0      56644
# 20.0      52028
# 55.0      47184
# 80.0      39572
# 50.0      33077
# 15.0      30853
# 25.0      24495
# 85.0      24134
# 45.0      20661
# 90.0      15374
# 40.0      15006
# 30.0      12428
# 35.0      11656
# 95.0      11008
# 100.0      5426
# 105.0      3175
# 110.0      2019
# 115.0      1484
# 10.0       1313
# 120.0       999
# 125.0       724
# 130.0       546
# 135.0       398
# 145.0       287
# 140.0       276
# 150.0       189
# 155.0       167
# 160.0       129
# 180.0       104
# 170.0        98
# 165.0        93
# 185.0        69
# 190.0        69
# 175.0        56
# 210.0        55
# 200.0        47
# 230.0        45
# 195.0        44
# 220.0        36
# 250.0        26
# 240.0        24
# 260.0        24
# 270.0        23
# 290.0        21
# 340.0        13
# 310.0        12
# 320.0        12
# 390.0        11
# 330.0        11
# 360.0        10
# 450.0         9
# 370.0         9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 637351 entries, 23167208 to 24015318
# Data columns (total 19 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   種類            637351 non-null  object
#  1   市区町村コード       637351 non-null  int64
#  2   都道府県名         637351 non-null  object
#  3   地区名           637060 non-null  object
#  4   最寄駅：名称        634732 non-null  object
#  5   最寄駅：距離（分）     614306 non-null  float64
#  6   間取り           615609 non-null  object
#  7   面積（㎡）         637351 non-null  float64
#  8   建築年           619117 non-null  object
#  9   建物の構造         623423 non-null  object
#  10  用途            591214 non-null  object
#  11  今後の利用目的       275091 non-null  object
#  12  都市計画          618786 non-null  object
#  13  建ぺい率（％）       614848 non-null  float64
#  14  容積率（％）        614848 non-null  float64
#  15  取引時点          637351 non-null  object
#  16  改装            580431 non-null  object
# ...

# %%
df["建築年"].value_counts()
# Out:
# 建築年
# 平成3年     21982
# 平成20年    21947
# 平成18年    21719
# 平成19年    21398
# 平成10年    20749
# 平成15年    20732
# 平成12年    20551
# 平成17年    20465
# 平成7年     20426
# 平成2年     19921
# 平成8年     19534
# 平成14年    19468
# 平成9年     18887
# 平成13年    18749
# 平成11年    18570
# 平成16年    18359
# 昭和64年    16886
# 平成4年     16114
# 昭和63年    16009
# 平成21年    15380
# 平成6年     14287
# 昭和62年    13899
# 昭和59年    13736
# 昭和60年    13244
# 昭和61年    12658
# 昭和49年    11660
# 平成5年     10759
# 平成22年     9814
# 昭和54年     8801
# 昭和57年     8710
# 昭和55年     8566
# 昭和56年     8224
# 平成24年     7813
# 平成23年     7466
# 昭和48年     7347
# 昭和58年     7004
# 昭和53年     6808
# 平成25年     6530
# 昭和50年     6427
# 昭和52年     5519
# 平成26年     5353
# 昭和51年     5203
# 昭和47年     4833
# 平成27年     4616
# 昭和46年     4297
# 昭和45年     3669
# 平成28年     3138
# 昭和44年     2197
# 昭和43年     2064
# 平成29年     2012
# 平成30年     1272
# 昭和42年      876
# 平成31年      712
# 昭和41年      590
# 戦前         556
# 昭和40年      197
# 昭和39年      147
# 昭和38年       48
# ...

# %%
# "建築年"が和暦のため西暦になおしたい
# split("平成") ['', '3年']そこから[1]番目である'3年'の"年"を平成同様「3, ''」にする。そして最後に[0]番目である数字だけ取り出す
df["建築年"].value_counts().keys()[0].split("平成")[1].split("年")[0]
# Out:
# '3'

# %%
y_list = {}
for i in df["建築年"].value_counts().keys(): #keyを一つずつ取り出す
  if "平成" in i: #iの中に平成があれば
    num = float(i.split("平成")[1].split("年")[0]) #数字を取り出し格納
    year = 1988 + num #平成なので1988年に足す
  elif "令和" in i:
    num = float(i.split("令和")[1].split("年")[0])
    year = 2018 + num
  elif "昭和" in i:
    num = float(i.split("昭和")[1].split("年")[0])
    year = 1925 + num

  y_list[i] = year

y_list["戦前"] = 1945

y_list

df["建築年"] = df["建築年"].replace(y_list)
# Out:
# <ipython-input-32-3ad0cd6b0bc4>:19: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["建築年"] = df["建築年"].replace(y_list)

# %%
df["建築年"].value_counts()
# Out:
# 建築年
# 1991.0    21982
# 2008.0    21947
# 2006.0    21719
# 2007.0    21398
# 1998.0    20749
# 2003.0    20732
# 2000.0    20551
# 2005.0    20465
# 1995.0    20426
# 1990.0    19921
# 1996.0    19534
# 2002.0    19468
# 1997.0    18887
# 2001.0    18749
# 1999.0    18570
# 2004.0    18359
# 1989.0    16886
# 1992.0    16114
# 1988.0    16009
# 2009.0    15380
# 1994.0    14287
# 1987.0    13899
# 1984.0    13736
# 1985.0    13244
# 1986.0    12658
# 1974.0    11660
# 1993.0    10759
# 2010.0     9814
# 1979.0     8801
# 1982.0     8710
# 1980.0     8566
# 1981.0     8224
# 2012.0     7813
# 2011.0     7466
# 1973.0     7347
# 1983.0     7004
# 1978.0     6808
# 2013.0     6530
# 1975.0     6427
# 1977.0     5519
# 2014.0     5353
# 1976.0     5203
# 1972.0     4833
# 2015.0     4616
# 1971.0     4297
# 1970.0     3669
# 2016.0     3138
# 1969.0     2197
# 1968.0     2064
# 2017.0     2012
# 2018.0     1272
# 1967.0      876
# 2019.0      712
# 1966.0      590
# 1945.0      556
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 637351 entries, 23167208 to 24015318
# Data columns (total 19 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   種類            637351 non-null  object
#  1   市区町村コード       637351 non-null  int64
#  2   都道府県名         637351 non-null  object
#  3   地区名           637060 non-null  object
#  4   最寄駅：名称        634732 non-null  object
#  5   最寄駅：距離（分）     614306 non-null  float64
#  6   間取り           615609 non-null  object
#  7   面積（㎡）         637351 non-null  float64
#  8   建築年           619117 non-null  float64
#  9   建物の構造         623423 non-null  object
#  10  用途            591214 non-null  object
#  11  今後の利用目的       275091 non-null  object
#  12  都市計画          618786 non-null  object
#  13  建ぺい率（％）       614848 non-null  float64
#  14  容積率（％）        614848 non-null  float64
#  15  取引時点          637351 non-null  object
#  16  改装            580431 non-null  object
# ...

# %%
df["取引時点"]
# Out:
# ID
# 23167208    2012年第３四半期
# 23071718    2015年第３四半期
# 23197007    2008年第２四半期
# 23132701    2010年第１四半期
# 23002332    2015年第３四半期
#                ...
# 24028351    2010年第４四半期
# 24040531    2013年第４四半期
# 24056543    2007年第４四半期
# 24013277    2015年第３四半期
# 24015318    2016年第２四半期
# Name: 取引時点, Length: 637351, dtype: object

# %% [markdown]
# 第1四半期→0.25
# 第2四半期→0.50
# 第3四半期→0.75
# 第4四半期→0.99
# に変換

# %%
"2012年第4四半期".replace("第4四半期", ".99") #左のような処理が必要
# Out:
# '2012年.99'

# %%
year = {
    "年第１四半期": ".25",
    "年第２四半期": ".50",
    "年第３四半期": ".75",
    "年第４四半期": ".99"
}

year_list = {}
for i in df["取引時点"].value_counts().keys():
  for k, j in year.items(): #year辞書の一つ一つをとりだす
    if k in i: #iにkが入っていたら
      year_rep = i.replace(k, j)
  year_list[i] = year_rep

  year_list[i]

df["取引時点"] = df["取引時点"].replace(year_list).astype(float)

# %%
df["取引時点"].value_counts().keys()
# Out:
# Index([2014.25, 2017.25, 2015.25, 2013.25,  2013.5, 2018.25, 2016.25,  2019.5,
#         2016.5, 2019.25, 2010.99, 2019.75,  2015.5, 2018.99, 2011.25, 2017.99,
#        2015.99,  2018.5, 2015.75, 2016.75, 2017.75, 2010.75, 2013.99, 2016.99,
#        2014.99, 2013.75, 2019.99, 2018.75, 2010.25,  2017.5, 2012.99, 2012.25,
#        2014.75,  2010.5,  2014.5, 2009.99,  2012.5, 2009.75, 2012.75, 2011.99,
#         2009.5, 2011.75, 2009.25,  2011.5, 2008.75, 2008.99,  2008.5, 2008.25,
#        2007.99,  2007.5, 2007.75, 2007.25, 2006.99, 2006.75,  2006.5, 2006.25,
#        2005.99, 2005.75],
#       dtype='float64', name='取引時点')

# %%
# year = {
#     "年第１四半期": ".25",
#     "年第２四半期": ".50",
#     "年第３四半期": ".75",
#     "年第４四半期": ".99"
# }

# for k, j in year.items(): #year辞書の一つ一つをとりだす
#   print(k)
#   print(j)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 637351 entries, 23167208 to 24015318
# Data columns (total 19 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   種類            637351 non-null  object
#  1   市区町村コード       637351 non-null  int64
#  2   都道府県名         637351 non-null  object
#  3   地区名           637060 non-null  object
#  4   最寄駅：名称        634732 non-null  object
#  5   最寄駅：距離（分）     614306 non-null  float64
#  6   間取り           615609 non-null  object
#  7   面積（㎡）         637351 non-null  float64
#  8   建築年           619117 non-null  float64
#  9   建物の構造         623423 non-null  object
#  10  用途            591214 non-null  object
#  11  今後の利用目的       275091 non-null  object
#  12  都市計画          618786 non-null  object
#  13  建ぺい率（％）       614848 non-null  float64
#  14  容積率（％）        614848 non-null  float64
#  15  取引時点          637351 non-null  float64
#  16  改装            580431 non-null  object
# ...

# %%
# 特徴量を追加する
df["築年数"] = df["取引時点"] - df["建築年"]

# %%
df["築年数"]
# Out:
# ID
# 23167208    15.75
# 23071718    40.75
# 23197007     5.50
# 23132701     7.25
# 23002332    29.75
#             ...
# 24028351    11.99
# 24040531    13.99
# 24056543     3.99
# 24013277    26.75
# 24015318    24.50
# Name: 築年数, Length: 637351, dtype: float64

# %%
df.describe()
# Out:
#              市区町村コード      最寄駅：距離（分）          面積（㎡）            建築年  \
# count  637351.000000  614306.000000  637351.000000  619117.000000
# mean    18513.985300      11.731487      58.663570    1995.021920
# std      9596.722442      12.197090      26.712019      11.496701
# min      1101.000000       0.000000      10.000000    1945.000000
# 25%     13106.000000       5.000000      45.000000    1987.000000
# 50%     14104.000000       8.000000      65.000000    1996.000000
# 75%     27114.000000      14.000000      75.000000    2004.000000
# max     47213.000000     120.000000    2000.000000    2020.000000
#
#              建ぺい率（％）         容積率（％）           取引時点   取引価格（総額）_log  \
# count  614848.000000  614848.000000  637351.000000  637351.000000
# mean       67.601944     301.601876    2013.633153       7.217424
# std        10.402295     148.105400       3.884546       0.353935
# min        30.000000      50.000000    2005.750000       2.653213
# ...

# %%
# ヒストグラムで可視化
flg, axes = plt.subplots(2, 2, figsize=(10, 10)) #4行、１列の箱を作成。figには箱の情報。axesにはそれぞれのグラフ
axes[0][0].hist(df["最寄駅：距離（分）"], bins=20) #0行目の0列目
axes[0][1].hist(df["面積（㎡）"], bins=200)
axes[0][1].set_xlim(0, 250) #250まででx軸の右側切り捨てる
axes[1][0].hist(df["築年数"], bins=20)
axes[1][1].hist(df["取引価格（総額）_log"], bins=20)
# plt.hist(df["最寄駅：距離（分）"], bins=20)
plt.show()

# %%
# 相関関係を確認
df[["取引価格（総額）_log", "最寄駅：距離（分）", "面積（㎡）", "築年数"]].corr()
# Out:
#               取引価格（総額）_log  最寄駅：距離（分）     面積（㎡）       築年数
# 取引価格（総額）_log      1.000000  -0.215520  0.382755 -0.502168
# 最寄駅：距離（分）        -0.215520   1.000000  0.151880  0.105801
# 面積（㎡）             0.382755   0.151880  1.000000 -0.070558
# 築年数              -0.502168   0.105801 -0.070558  1.000000

# %%
# 築年数が古いほど、取引価格は安く、面積が大きいほど取引価格が高いことがわかる
