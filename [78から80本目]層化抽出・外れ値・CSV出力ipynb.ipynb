# %% [markdown]
# <a href="https://colab.research.google.com/github/RYOTA2528/data_analysis_practice/blob/main/%5B78%E3%81%8B%E3%82%8980%E6%9C%AC%E7%9B%AE%5D%E5%B1%A4%E5%8C%96%E6%8A%BD%E5%87%BA%E3%83%BB%E5%A4%96%E3%82%8C%E5%80%A4%E3%83%BBCSV%E5%87%BA%E5%8A%9Bipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## [1から5本目]データの読み込みから型変換まで

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
sales_df = pd.read_csv("/content/drive/MyDrive/Python100本ノック用/Sales_Data.csv")
member_df = pd.read_csv("/content/drive/MyDrive/Python100本ノック用/Member_Data.csv")

# %%
sales_df.head(5)
# Out:
#    Transaction_ID Transaction_Date  Member_ID  Product_ID  Store_ID  Quantity  \
# 0               1    2024/5/1 0:00         21          25        12         3
# 1               2    2024/5/1 2:55        107          23        17         1
# 2               3    2024/5/1 5:51        117          24         6         3
# 3               4    2024/5/1 8:47        124          38         1         3
# 4               5   2024/5/1 11:43        281          28         5         4
#
#    Amount
# 0    5820
# 1     640
# 2    1270
# 3    5980
# 4    9390

# %%
member_df.tail(5)
# Out:
#      Member_ID  Gender  Age  Days_Since_Registration
# 295        296    Male   41                     1513
# 296        297  Female   58                     1613
# 297        298  Female   71                     1177
# 298        299  Female   38                     1660
# 299        300  Female   50                      104

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    1000 non-null   int64
#  1   Transaction_Date  1000 non-null   object
#  2   Member_ID         1000 non-null   int64
#  3   Product_ID        1000 non-null   int64
#  4   Store_ID          1000 non-null   int64
#  5   Quantity          1000 non-null   int64
#  6   Amount            1000 non-null   int64
# dtypes: int64(6), object(1)
# memory usage: 54.8+ KB

# %%
# 各種IDを文字列に変換
sales_df["Transaction_ID"] = sales_df["Transaction_ID"].astype("string")
sales_df["Member_ID"] = sales_df["Member_ID"].astype("string")
sales_df["Product_ID"] = sales_df["Product_ID"].astype("string")
sales_df["Store_ID"] = sales_df["Store_ID"].astype("string")
sales_df["Transaction_ID"] = sales_df["Transaction_ID"].astype("string")

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    1000 non-null   string
#  1   Transaction_Date  1000 non-null   object
#  2   Member_ID         1000 non-null   string
#  3   Product_ID        1000 non-null   string
#  4   Store_ID          1000 non-null   string
#  5   Quantity          1000 non-null   int64
#  6   Amount            1000 non-null   int64
# dtypes: int64(2), object(1), string(4)
# memory usage: 54.8+ KB

# %% [markdown]
# ## [6から10本目]データの型変換からqueryの使い方まで

# %%
#[6] 日付データをdataTime型に変換
# sales_df["Transcation_Date"] = pd.to_datetime(sales_df["Transcation_Date"])
sales_df["Transaction_Date"] = pd.to_datetime(sales_df["Transaction_Date"] )

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    1000 non-null   string
#  1   Transaction_Date  1000 non-null   datetime64[ns]
#  2   Member_ID         1000 non-null   string
#  3   Product_ID        1000 non-null   string
#  4   Store_ID          1000 non-null   string
#  5   Quantity          1000 non-null   int64
#  6   Amount            1000 non-null   int64
# dtypes: datetime64[ns](1), int64(2), string(4)
# memory usage: 54.8 KB

# %%
#[7] 取引データの各列の基本的な統計情報の表示
sales_df.describe()
# Out:
#                     Transaction_Date     Quantity        Amount
# count                           1000  1000.000000   1000.000000
# mean   2024-06-30 23:59:30.299999744     2.551000   5338.650000
# min              2024-05-01 00:00:00     1.000000    510.000000
# 25%              2024-05-31 11:59:15     2.000000   3022.500000
# 50%              2024-06-30 23:59:30     3.000000   5250.000000
# 75%              2024-07-31 11:59:45     4.000000   7752.500000
# max              2024-08-31 00:00:00     4.000000  10000.000000
# std                              NaN     1.103003   2778.234487

# %%
# [8]カラム名の変更
sales_df.rename(columns={"Amount": "Sales_Amount"})
sales_df.rename(columns={"Amount": "Sales Amount"})
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 0                1 2024-05-01 00:00:00        21         25       12
# 1                2 2024-05-01 02:55:00       107         23       17
# 2                3 2024-05-01 05:51:00       117         24        6
# 3                4 2024-05-01 08:47:00       124         38        1
# 4                5 2024-05-01 11:43:00       281         28        5
# ..             ...                 ...       ...        ...      ...
# 995            996 2024-08-30 12:16:00       213         33       15
# 996            997 2024-08-30 15:12:00        62         49       19
# 997            998 2024-08-30 18:08:00        49         12       11
# 998            999 2024-08-30 21:04:00       127         11       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Sales Amount
# 0           3          5820
# 1           1           640
# 2           3          1270
# 3           3          5980
# 4           4          9390
# ..        ...           ...
# 995         3          8400
# 996         3          3930
# 997         4          2530
# 998         3          4160
# 999         2          7530
#
# [1000 rows x 7 columns]

# %%
# [9] Amountを100円単に四捨五入
sales_df["Amount"].round(-2)
# Out:
# 0      5800
# 1       600
# 2      1300
# 3      6000
# 4      9400
#        ...
# 995    8400
# 996    3900
# 997    2500
# 998    4200
# 999    7500
# Name: Amount, Length: 1000, dtype: int64

# %%
# [10] 取引データからAmountが5000円を超える取引を抽出
sales_df.query("Amount > 5000")
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 0                1 2024-05-01 00:00:00        21         25       12
# 3                4 2024-05-01 08:47:00       124         38        1
# 4                5 2024-05-01 11:43:00       281         28        5
# 5                6 2024-05-01 14:39:00       292         21       14
# 6                7 2024-05-01 17:35:00       203         43        5
# ..             ...                 ...       ...        ...      ...
# 991            992 2024-08-30 00:33:00       258         19       14
# 992            993 2024-08-30 03:29:00        81         18       13
# 994            995 2024-08-30 09:20:00       235          8       12
# 995            996 2024-08-30 12:16:00       213         33       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Amount
# 0           3    5820
# 3           3    5980
# 4           4    9390
# 5           4    8730
# 6           3    9830
# ..        ...     ...
# 991         1    7220
# 992         3    7610
# 994         1    7880
# 995         3    8400
# 999         2    7530
#
# [535 rows x 7 columns]

# %% [markdown]
# ## [11から15本目]queryの様々な使い方(ノック)

# %%
# [11]会員データから30歳から50歳の会員を抽出してください
member_df.query("30 <= Age <=50")
# Out:
#      Member_ID  Gender  Age  Days_Since_Registration
# 3            4  Female   49                     1881
# 8            9    Male   48                     1640
# 9           10  Female   48                     1317
# 12          13    Male   41                     1855
# 13          14    Male   33                      928
# ..         ...     ...  ...                      ...
# 292        293  Female   35                      388
# 293        294    Male   32                     1127
# 295        296    Male   41                     1513
# 298        299  Female   38                     1660
# 299        300  Female   50                      104
#
# [114 rows x 4 columns]

# %%
# [12]取引データから"2024-08-01"以降に行われた取引を抽出
sales_df.query("Transaction_Date >= '2024-08-01'") #''で囲うこと
# sales_df.columns
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 754            755 2024-08-01 01:55:00       226         17       14
# 755            756 2024-08-01 04:51:00       131         18       18
# 756            757 2024-08-01 07:47:00        76         45       13
# 757            758 2024-08-01 10:42:00       286         29       11
# 758            759 2024-08-01 13:38:00       277         20       16
# ..             ...                 ...       ...        ...      ...
# 995            996 2024-08-30 12:16:00       213         33       15
# 996            997 2024-08-30 15:12:00        62         49       19
# 997            998 2024-08-30 18:08:00        49         12       11
# 998            999 2024-08-30 21:04:00       127         11       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Amount
# 754         4    8640
# 755         3     960
# 756         3    1910
# 757         1    4430
# 758         1    5090
# ..        ...     ...
# 995         3    8400
# 996         3    3930
# 997         4    2530
# 998         3    4160
# 999         2    7530
#
# [246 rows x 7 columns]

# %%
# [13]Store_ID が「1」または「3」で、かつ Amount が5000円以上の取引を抽出
sales_df.query("(Store_ID == '1' or Store_ID == '3') and Amount >= 5000")
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 3                4 2024-05-01 08:47:00       124         38        1
# 7                8 2024-05-01 20:30:00        51         18        1
# 17              18 2024-05-03 01:49:00       156          3        1
# 61              62 2024-05-08 10:47:00        50         38        3
# 65              66 2024-05-08 22:30:00        60         49        3
# 86              87 2024-05-11 12:03:00        77         37        1
# 95              96 2024-05-12 14:26:00       167          9        1
# 109            110 2024-05-14 07:28:00       229         49        3
# 129            130 2024-05-16 18:05:00       259          1        1
# 138            139 2024-05-17 20:28:00       116         17        3
# 151            152 2024-05-19 10:34:00       136         17        3
# 188            189 2024-05-23 23:00:00        12         11        1
# 189            190 2024-05-24 01:56:00       239         50        3
# 202            203 2024-05-25 16:02:00        73          9        3
# 210            211 2024-05-26 15:29:00        25          8        1
# 279            280 2024-06-04 01:43:00       133          3        1
# 280            281 2024-06-04 04:39:00       183         14        1
# 287            288 2024-06-05 01:10:00       138         38        1
# 305            306 2024-06-07 05:56:00        52          8        3
# 309            310 2024-06-07 17:39:00       232         29        1
# 313            314 2024-06-08 05:22:00        42         17        3
# 318            319 2024-06-08 20:02:00       192         19        1
# 360            361 2024-06-13 23:08:00       261         26        3
# 392            393 2024-06-17 20:55:00       273         48        3
# 441            442 2024-06-23 20:32:00       118          7        1
# 443            444 2024-06-24 02:24:00        23         13        1
# 446            447 2024-06-24 11:11:00       108         13        3
# 483            484 2024-06-28 23:38:00       111         49        3
# 491            492 2024-06-29 23:05:00       202         38        3
# 492            493 2024-06-30 02:01:00        38         24        3
# 547            548 2024-07-06 19:13:00        90         11        1
# 554            555 2024-07-07 15:44:00       254         22        3
# 615            616 2024-07-15 02:31:00       165         50        3
# 643            644 2024-07-18 12:35:00         2         29        3
# 647            648 2024-07-19 00:18:00        66         43        1
# 701            702 2024-07-25 14:34:00        47         24        3
# 710            711 2024-07-26 16:57:00       114         36        3
# 732            733 2024-07-29 09:26:00       162         10        1
# 775            776 2024-08-03 15:28:00       289         17        3
# 782            783 2024-08-04 11:59:00       201          5        1
# 788            789 2024-08-05 05:34:00       191         19        1
# 797            798 2024-08-06 07:57:00       142         14        1
# 808            809 2024-08-07 16:11:00        46         48        3
# 837            838 2024-08-11 05:11:00       164         23        3
# 845            846 2024-08-12 04:38:00       222         40        1
# 860            861 2024-08-14 00:36:00       158         41        3
# 867            868 2024-08-14 21:07:00       149         25        3
# 873            874 2024-08-15 14:42:00        65         36        3
# 885            886 2024-08-17 01:52:00       276         32        1
# 891            892 2024-08-17 19:27:00        76         10        1
# 946            947 2024-08-24 12:39:00        72         43        1
# 947            948 2024-08-24 15:35:00       109         35        1
# 953            954 2024-08-25 09:10:00         8          4        3
# 968            969 2024-08-27 05:08:00       225         13        3
#
#      Quantity  Amount
# 3           3    5980
# 7           4    5510
# 17          3    7620
# 61          4    6490
# 65          2    5790
# 86          2    8500
# 95          3    5370
# 109         4    9850
# 129         2    9480
# 138         1    9840
# 151         1    8150
# 188         2    9920
# 189         3    8000
# 202         2    6070
# 210         4    9390
# 279         4    8210
# 280         1    5570
# 287         2    8160
# 305         2    9410
# 309         1    8290
# 313         1    7300
# 318         3    7440
# 360         3    6150
# 392         3    6890
# 441         4    6990
# 443         2    9340
# 446         4    7820
# 483         1    6770
# 491         4    8010
# 492         2    8130
# 547         3    7760
# 554         1    8670
# 615         1    5610
# 643         2    8570
# 647         2    8580
# 701         2    7560
# 710         4    9660
# 732         1    8090
# 775         1    5980
# 782         1    8260
# 788         3    8120
# 797         4    5850
# 808         4    5130
# 837         2    9310
# 845         4    8850
# 860         3    6620
# 867         1    8100
# 873         3    9000
# 885         3    5760
# 891         1    6690
# 946         2    7610
# 947         1    9110
# 953         2    7310
# 968         2    6820

# %%
# [14] Product_ID が「10」、「20」、「30」のいずれかに一致する取引
sales_df.query("Product_ID in ['10', '20', '30']")
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 13              14 2024-05-02 14:06:00        52         30        2
# 41              42 2024-05-06 00:10:00        47         20       12
# 44              45 2024-05-06 08:57:00       277         10       10
# 69              70 2024-05-09 10:14:00       164         30        9
# 84              85 2024-05-11 06:11:00       138         30        2
# 167            168 2024-05-21 09:27:00       288         20        5
# 227            228 2024-05-28 17:19:00       288         10        9
# 236            237 2024-05-29 19:41:00        43         30       17
# 237            238 2024-05-29 22:37:00       254         30       12
# 247            248 2024-05-31 03:56:00       253         30       16
# 273            274 2024-06-03 08:08:00         7         30       19
# 315            316 2024-06-08 11:14:00        42         30       11
# 326            327 2024-06-09 19:29:00        97         10       14
# 327            328 2024-06-09 22:24:00        10         10       19
# 330            331 2024-06-10 07:12:00       277         20        9
# 340            341 2024-06-11 12:30:00        69         30        2
# 402            403 2024-06-19 02:14:00       113         10        8
# 418            419 2024-06-21 01:07:00       224         30       18
# 421            422 2024-06-21 09:55:00        86         20       15
# 484            485 2024-06-29 02:34:00       132         10        6
# 487            488 2024-06-29 11:21:00       227         10       17
# 498            499 2024-06-30 19:36:00       119         10       19
# 514            515 2024-07-02 18:29:00       188         20        4
# 525            526 2024-07-04 02:44:00       228         30       12
# 575            576 2024-07-10 05:17:00       182         20       14
# 590            591 2024-07-12 01:14:00       182         10        8
# 617            618 2024-07-15 08:23:00        82         20        8
# 635            636 2024-07-17 13:08:00        86         10        2
# 639            640 2024-07-18 00:51:00       198         30        6
# 641            642 2024-07-18 06:43:00        65         30        8
# 691            692 2024-07-24 09:16:00       197         30       19
# 695            696 2024-07-24 20:59:00         8         30        7
# 700            701 2024-07-25 11:39:00        55         20        3
# 709            710 2024-07-26 14:01:00       283         10       14
# 732            733 2024-07-29 09:26:00       162         10        1
# 744            745 2024-07-30 20:36:00       154         20        7
# 745            746 2024-07-30 23:32:00       133         20        5
# 746            747 2024-07-31 02:28:00       227         30       17
# 758            759 2024-08-01 13:38:00       277         20       16
# 767            768 2024-08-02 16:01:00        75         20       12
# 769            770 2024-08-02 21:53:00       176         10        1
# 801            802 2024-08-06 19:40:00       210         20        6
# 844            845 2024-08-12 01:42:00       227         10        8
# 850            851 2024-08-12 19:17:00         2         20        4
# 865            866 2024-08-14 15:15:00        50         30       10
# 884            885 2024-08-16 22:56:00        38         10       16
# 891            892 2024-08-17 19:27:00        76         10        1
# 926            927 2024-08-22 02:02:00       233         20        2
# 975            976 2024-08-28 01:39:00       202         10       17
# 977            978 2024-08-28 07:31:00       210         20        6
#
#      Quantity  Amount
# 13          1    8650
# 41          1    3060
# 44          4    6870
# 69          3    4650
# 84          3    1750
# 167         1    6520
# 227         4    3570
# 236         3    9630
# 237         3    6460
# 247         4    1090
# 273         4    4090
# 315         3    3650
# 326         3    4760
# 327         4    5540
# 330         3    2680
# 340         4    1580
# 402         3    5060
# 418         2    2380
# 421         4    8750
# 484         2    7440
# 487         2    3920
# 498         2    2220
# 514         1    1770
# 525         4    8200
# 575         4    5880
# 590         2    1430
# 617         2    3290
# 635         4    2170
# 639         2    3120
# 641         3    3990
# 691         2    3150
# 695         4    9220
# 700         3    2440
# 709         3    6310
# 732         1    8090
# 744         3    9310
# 745         3    6820
# 746         3    7060
# 758         1    5090
# 767         2    7130
# 769         1    4220
# 801         2    6810
# 844         3    8320
# 850         4    1970
# 865         3    6550
# 884         3    5690
# 891         1    6690
# 926         4    7020
# 975         2    9790
# 977         4    5070

# %%
# [15]  Product_ID が「10」、「20」、「30」ではない取引を抽出
sales_df.query("Product_ID not in ['10', '20', '30']")
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 0                1 2024-05-01 00:00:00        21         25       12
# 1                2 2024-05-01 02:55:00       107         23       17
# 2                3 2024-05-01 05:51:00       117         24        6
# 3                4 2024-05-01 08:47:00       124         38        1
# 4                5 2024-05-01 11:43:00       281         28        5
# ..             ...                 ...       ...        ...      ...
# 995            996 2024-08-30 12:16:00       213         33       15
# 996            997 2024-08-30 15:12:00        62         49       19
# 997            998 2024-08-30 18:08:00        49         12       11
# 998            999 2024-08-30 21:04:00       127         11       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Amount
# 0           3    5820
# 1           1     640
# 2           3    1270
# 3           3    5980
# 4           4    9390
# ..        ...     ...
# 995         3    8400
# 996         3    3930
# 997         4    2530
# 998         3    4160
# 999         2    7530
#
# [950 rows x 7 columns]

# %% [markdown]
# ## [16から20本目]queryの使い方(続き)からgroupbyの使い方

# %%
# [16] Quantity が最頻値で、かつ Store_ID が「3」の取引を抽出
mode_quantity = sales_df["Quantity"].mode() #mode()で最頻値取得
# mode_quantity
sales_df.query("Quantity == @mode_quantity and Store_ID == '3'") #変数取得は@
# Out:
# Empty DataFrame
# Columns: [Transaction_ID, Transaction_Date, Member_ID, Product_ID, Store_ID, Quantity, Amount]
# Index: []

# %%
# [17] Amount が第1四分位(25%の箇所)から第3四分位(75%の箇所)の範囲に属する取引を抽出
q1 = sales_df["Amount"].quantile(0.25)
q3 = sales_df["Amount"].quantile(0.75)
sales_df.query("@q1 >= Amount <= @q3")
# print(q1)
# print(q3)
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 1                2 2024-05-01 02:55:00       107         23       17
# 2                3 2024-05-01 05:51:00       117         24        6
# 16              17 2024-05-02 22:53:00       239         32        4
# 32              33 2024-05-04 21:47:00       159         34        6
# 36              37 2024-05-05 09:30:00        36          4       18
# ..             ...                 ...       ...        ...      ...
# 982            983 2024-08-28 22:10:00        28          2        5
# 984            985 2024-08-29 04:02:00        84         37        6
# 986            987 2024-08-29 09:53:00       117          7       18
# 993            994 2024-08-30 06:24:00       268         16        7
# 997            998 2024-08-30 18:08:00        49         12       11
#
#      Quantity  Amount
# 1           1     640
# 2           3    1270
# 16          3    2680
# 32          2    3000
# 36          4    2430
# ..        ...     ...
# 982         2    2020
# 984         4    2720
# 986         2     790
# 993         1    2370
# 997         4    2530
#
# [250 rows x 7 columns]

# %%
# [18] Product_IDとStore_IDは何種類あるか確認
print(sales_df['Product_ID'].nunique())
print(sales_df['Store_ID'].nunique())
# Out:
# 50
# 20

# %%
# [19] 取引データのProduct_ID ごとに Amount の合計を計算
sales_df.groupby("Product_ID")["Amount"].sum()
# Out:
# Product_ID
# 1     121370
# 10     92090
# 11    138860
# 12     63900
# 13    139100
# 14     70100
# 15     68080
# 16    105910
# 17    169320
# 18    110060
# 19    130610
# 2      49920
# 20     83610
# 21    111740
# 22    128200
# 23    106680
# 24    114060
# 25     88820
# 26    101690
# 27    102510
# 28    121120
# 29    125780
# 3     110040
# 30     85220
# 31    106200
# 32    125020
# 33     58490
# 34    126490
# 35    123210
# 36    172620
# 37    126730
# 38    130600
# 39     77480
# 4     122830
# 40    110710
# 41    110640
# 42     77460
# 43    101910
# 44     97120
# 45    148920
# 46     55560
# 47    156200
# 48     78090
# 49    118600
# 5      76510
# 50    111310
# 6      84720
# 7      94250
# 8     135630
# 9      72560
# Name: Amount, dtype: int64

# %%
# 20 Product_ID ごとにQuantityの中央値を計算
sales_df.groupby("Product_ID")["Quantity"].median()
# Out:
# Product_ID
# 1     2.0
# 10    3.0
# 11    3.0
# 12    3.0
# 13    2.0
# 14    3.0
# 15    2.5
# 16    3.0
# 17    2.0
# 18    3.0
# 19    2.0
# 2     2.0
# 20    3.0
# 21    2.5
# 22    3.0
# 23    2.0
# 24    2.0
# 25    3.0
# 26    2.0
# 27    2.0
# 28    3.0
# 29    3.0
# 3     3.0
# 30    3.0
# 31    3.0
# 32    3.0
# 33    3.0
# 34    3.0
# 35    3.0
# 36    3.0
# 37    3.0
# 38    3.0
# 39    3.0
# 4     2.0
# 40    2.0
# 41    2.0
# 42    3.0
# 43    2.0
# 44    2.5
# 45    3.0
# 46    2.0
# 47    2.0
# 48    2.5
# 49    3.0
# 5     3.0
# 50    2.0
# 6     3.0
# 7     2.0
# 8     2.0
# 9     3.0
# Name: Quantity, dtype: float64

# %% [markdown]
# ## [21から25本目]日付の扱いとソートの使い方

# %%
# [21] Store_ID ごとに平均Amountを集計してください
sales_df.groupby("Store_ID")["Amount"].mean()
# Out:
# Store_ID
# 1     5875.111111
# 10    5295.961538
# 11    4872.400000
# 12    5615.681818
# 13    5811.186441
# 14    5879.111111
# 15    5587.343750
# 16    5189.803922
# 17    4724.492754
# 18    4887.916667
# 19    5099.361702
# 2     4632.142857
# 20    5076.923077
# 3     5507.450980
# 4     5329.512195
# 5     5687.500000
# 6     5362.037037
# 7     5456.410256
# 8     5434.426230
# 9     5622.857143
# Name: Amount, dtype: float64

# %%
# [22] 会員データの性別 (Gender) ごとに平均年齢を計算
member_df.groupby("Gender")["Age"].mean()
# Out:
# Gender
# Female    48.945205
# Male      53.259740
# Name: Age, dtype: float64

# %%
# [23] 会員ごとに平均Amountを計算してください
sales_df.groupby("Member_ID")["Amount"].mean()
# Out:
# Member_ID
# 1      4985.000000
# 10     6360.000000
# 100    7140.000000
# 101    6085.000000
# 102    4297.500000
#           ...
# 95     1310.000000
# 96     3330.000000
# 97     3036.666667
# 98     5533.333333
# 99     7915.000000
# Name: Amount, Length: 288, dtype: float64

# %%
# [24] Transaction_Dateから日付だけ取り出して日付ごとに Amount の合計を集計
sales_df["Transaction_Date_yyyyMMdd"] = sales_df['Transaction_Date'].dt.date #日付だけとりだす
sales_df["Transaction_Date_yyyyMMdd"]
sales_df.groupby("Transaction_Date_yyyyMMdd")["Amount"].sum()
# Out:
# Transaction_Date_yyyyMMdd
# 2024-05-01    55160
# 2024-05-02    47770
# 2024-05-03    52060
# 2024-05-04    38830
# 2024-05-05    47370
#               ...
# 2024-08-27    42500
# 2024-08-28    34250
# 2024-08-29    42680
# 2024-08-30    44100
# 2024-08-31     7530
# Name: Amount, Length: 123, dtype: int64

# %%
# [25] 日付ごとの合計Amountを集計し、合計Amountが小さい順にソート
# "Transaction_Date_yyyyMMdd" の日付がインデックスになっているため、まずはreset_index()で構造を見やすくする
sales_df.groupby("Transaction_Date_yyyyMMdd")["Amount"].sum().reset_index().sort_values(by="Amount", ascending=True)
# Out:
#     Transaction_Date_yyyyMMdd  Amount
# 122                2024-08-31    7530
# 51                 2024-06-21   24120
# 20                 2024-05-21   25140
# 114                2024-08-23   28120
# 68                 2024-07-08   28970
# ..                        ...     ...
# 24                 2024-05-25   57490
# 39                 2024-06-09   57500
# 117                2024-08-26   59750
# 84                 2024-07-24   60630
# 67                 2024-07-07   66030
#
# [123 rows x 2 columns]

# %% [markdown]
# ## [26から30本目]週や曜日ごとの集計方法

# %%
# [26] 月ごとに Amount を集計
sales_df["Month"] = sales_df['Transaction_Date'].dt.to_period("M")
sales_df.groupby("Month")["Amount"].sum()
# Out:
# Month
# 2024-05    1374890
# 2024-06    1282280
# 2024-07    1355570
# 2024-08    1325910
# Freq: M, Name: Amount, dtype: int64

# %%
# [27] 月ごとのAmountの増減の絶対値を前月と比較して計算
monthly_sales = sales_df.groupby("Month")["Amount"].sum().reset_index()
monthly_sales["Amount"].diff()
# Out:
# 0        NaN
# 1   -92610.0
# 2    73290.0
# 3   -29660.0
# Name: Amount, dtype: float64

# %%
# [28] 曜日ごとの合計Amountを集計
sales_df["Day_of_Week"] = sales_df['Transaction_Date'].dt.day_name()
sales_df.groupby("Day_of_Week")["Amount"].sum()
# Out:
# Day_of_Week
# Friday       745610
# Monday       719260
# Saturday     752010
# Sunday       765580
# Thursday     791610
# Tuesday      722620
# Wednesday    841960
# Name: Amount, dtype: int64

# %%
# [29] 1週間ごとに合計Amountを集計
sales_df["Week"] = sales_df["Transaction_Date"].dt.to_period("W")
sales_df.groupby("Week")["Amount"].sum()
# Out:
# Week
# 2024-04-29/2024-05-05    241190
# 2024-05-06/2024-05-12    311410
# 2024-05-13/2024-05-19    305180
# 2024-05-20/2024-05-26    309750
# 2024-05-27/2024-06-02    290200
# 2024-06-03/2024-06-09    312650
# 2024-06-10/2024-06-16    300020
# 2024-06-17/2024-06-23    281970
# 2024-06-24/2024-06-30    304800
# 2024-07-01/2024-07-07    319920
# 2024-07-08/2024-07-14    287650
# 2024-07-15/2024-07-21    309950
# 2024-07-22/2024-07-28    287240
# 2024-07-29/2024-08-04    315990
# 2024-08-05/2024-08-11    279250
# 2024-08-12/2024-08-18    344090
# 2024-08-19/2024-08-25    306580
# 2024-08-26/2024-09-01    230810
# Freq: W-SUN, Name: Amount, dtype: int64

# %%
# [30] 1週間ごとのAmountの増減を計算し、増加率をパーセンテージで表示
weekly_sales = sales_df.groupby("Week")["Amount"].sum().reset_index()
weekly_sales["Amount"].pct_change()*100 #pct_change()*100で%だせる
# Out:
# 0           NaN
# 1     29.113977
# 2     -2.000578
# 3      1.497477
# 4     -6.311542
# 5      7.736044
# 6     -4.039661
# 7     -6.016266
# 8      8.096606
# 9      4.960630
# 10   -10.086897
# 11     7.752477
# 12    -7.326988
# 13    10.009052
# 14   -11.626950
# 15    23.219338
# 16   -10.901218
# 17   -24.714593
# Name: Amount, dtype: float64

# %% [markdown]
# ## [31から35本目]週Groupbyとqueryの組み合わせで集計

# %%
# [31] 新しく作成したカラムを削除
sales_df.drop(["Transaction_Date_yyyyMMdd", "Month", "Day_of_Week", "Week"], axis=1, inplace=True) #axis=1は列方向
sales_df
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 0                1 2024-05-01 00:00:00        21         25       12
# 1                2 2024-05-01 02:55:00       107         23       17
# 2                3 2024-05-01 05:51:00       117         24        6
# 3                4 2024-05-01 08:47:00       124         38        1
# 4                5 2024-05-01 11:43:00       281         28        5
# ..             ...                 ...       ...        ...      ...
# 995            996 2024-08-30 12:16:00       213         33       15
# 996            997 2024-08-30 15:12:00        62         49       19
# 997            998 2024-08-30 18:08:00        49         12       11
# 998            999 2024-08-30 21:04:00       127         11       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Amount
# 0           3    5820
# 1           1     640
# 2           3    1270
# 3           3    5980
# 4           4    9390
# ..        ...     ...
# 995         3    8400
# 996         3    3930
# 997         4    2530
# 998         3    4160
# 999         2    7530
#
# [1000 rows x 7 columns]

# %%
# [32] Amount が1000円を超える取引を抽出し、Store_ID と Product_ID ごとに Amount の合計を計算
filtered_sales = sales_df.query("Amount > 1000") #Amountが1000円を超えてるもので変数化
filtered_sales.groupby(["Store_ID", "Product_ID"])["Amount"].sum()
# Out:
# Store_ID  Product_ID
# 1         1              9480
#           10            19000
#           11            17680
#           13             9340
#           14            11420
#                         ...
# 9         47             4520
#           48             5470
#           5              3940
#           6             15510
#           8              3280
# Name: Amount, Length: 597, dtype: int64

# %%
# [33] Store_ID ごとの合計Amountを集計し300000円以上の店舗を抽出
store_sales = sales_df.groupby("Store_ID")["Amount"].sum().reset_index()
store_sales.query("Amount > 300000")
# Out:
#    Store_ID  Amount
# 4        13  342860
# 6        15  357590
# 8        17  325990
# 18        8  331500

# %%
# [34] 会員ごとに取引回数をカウント
sales_df.groupby("Member_ID")["Transaction_ID"].count()
# Out:
# Member_ID
# 1      2
# 10     4
# 100    3
# 101    6
# 102    4
#       ..
# 95     2
# 96     1
# 97     3
# 98     3
# 99     2
# Name: Transaction_ID, Length: 288, dtype: int64

# %%
# [35] 会員ごとに取引回数をカウントし、2回以上の取引がある会員を抽出
transaction_count = sales_df.groupby("Member_ID")["Transaction_ID"].count().reset_index()
transaction_count.query("Transaction_ID >= 2")
# Out:
#     Member_ID  Transaction_ID
# 0           1               2
# 1          10               4
# 2         100               3
# 3         101               6
# 4         102               4
# ..        ...             ...
# 282        93               3
# 283        95               2
# 285        97               3
# 286        98               3
# 287        99               2
#
# [252 rows x 2 columns]

# %% [markdown]
# ## [36から40本目]新たな質的変数の定義とデータセットのマージ方法.

# %%
# [36] 年齢グループ（-30歳、31-50歳、51-65歳、66歳-）を作成し、各グループの会員数を集計
age_bins = [min(member_df["Age"])-1, 30, 50,65, max(member_df["Age"])] #min,maxと間
age_labels = ["-30", "31-50", "51-65", "66-"] #labelを作成
member_df["Age_Group"] = pd.cut(member_df["Age"], bins=age_bins, labels=age_labels)
member_df
member_df.groupby("Age_Group")["Member_ID"].count()
# ※min(member_df["Age"])-1 と記載してる理由は、ex(値+1の値を参照してるので)minが18歳でも19歳となってしまう
# Out:
# <ipython-input-45-526dacd1b3ce>:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   member_df.groupby("Age_Group")["Member_ID"].count()
# Age_Group
# -30       49
# 31-50    103
# 51-65     59
# 66-       89
# Name: Member_ID, dtype: int64

# %%
# [37] 会員になってからの日数（Days_Since_Registration）のグループ（〜1年、1年〜2年, 2年〜）を作成し、各グループの会員数を集計
years_bins = [min(member_df["Days_Since_Registration"])-1, 365, 710, max(member_df["Days_Since_Registration"])] #min,maxと間
years_labels = ["1年", "1年-2年", "2年-"] #labelを作成
member_df["Year_Group"] = pd.cut(member_df["Days_Since_Registration"], bins=years_bins, labels=years_labels)
member_df
member_df.groupby("Year_Group")["Member_ID"].count()
# Out:
# <ipython-input-46-ed3547925fef>:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   member_df.groupby("Year_Group")["Member_ID"].count()
# Year_Group
# 1年        52
# 1年-2年     50
# 2年-      198
# Name: Member_ID, dtype: int64

# %%
# [38] 売上データと会員データを結合しmerged_dfとして定義
member_df["Member_ID"] = sales_df["Member_ID"].astype("string") #Member_IDをStringの型にする
merged_df = sales_df.merge(member_df, on= "Member_ID")
merged_df
# Out:
#      Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 0                 1 2024-05-01 00:00:00        21         25       12
# 1                 2 2024-05-01 02:55:00       107         23       17
# 2                 3 2024-05-01 05:51:00       117         24        6
# 3                 3 2024-05-01 05:51:00       117         24        6
# 4                 4 2024-05-01 08:47:00       124         38        1
# ...             ...                 ...       ...        ...      ...
# 1342            997 2024-08-30 15:12:00        62         49       19
# 1343            998 2024-08-30 18:08:00        49         12       11
# 1344            998 2024-08-30 18:08:00        49         12       11
# 1345            998 2024-08-30 18:08:00        49         12       11
# 1346            998 2024-08-30 18:08:00        49         12       11
#
#       Quantity  Amount  Gender  Age  Days_Since_Registration Age_Group  \
# 0            3    5820    Male   69                      730       66-
# 1            1     640  Female   18                      958       -30
# 2            3    1270    Male   66                     1976       66-
# 3            3    1270    Male   22                      288       -30
# 4            3    5980  Female   49                     1881     31-50
# ...        ...     ...     ...  ...                      ...       ...
# 1342         3    3930    Male   75                      578       66-
# 1343         4    2530    Male   51                      325     51-65
# 1344         4    2530  Female   24                     1514       -30
# 1345         4    2530    Male   56                      751     51-65
# 1346         4    2530    Male   71                      553       66-
#
#      Year_Group
# 0           2年-
# 1           2年-
# 2           2年-
# 3            1年
# 4           2年-
# ...         ...
# 1342      1年-2年
# 1343         1年
# 1344        2年-
# 1345        2年-
# 1346      1年-2年
#
# [1347 rows x 12 columns]

# %%
# [39] 性別 ごとに 平均Amount を計算
merged_df.groupby("Gender")["Amount"].mean()
# Out:
# Gender
# Female    5300.900322
# Male      5316.744828
# Name: Amount, dtype: float64

# %%
# [40] 性別ごとの平均 Quantity を集計
merged_df.groupby("Gender")["Quantity"].mean()
# Out:
# Gender
# Female    2.588424
# Male      2.566897
# Name: Quantity, dtype: float64

# %% [markdown]
# ## [41から45本目]日付の扱いとTOP5の集計方法

# %%
# [41] 性別と店舗IDごとに取引数を集計
merged_df.groupby(["Gender", "Store_ID"])["Transaction_ID"].count()
# Out:
# Gender  Store_ID
# Female  1           25
#         10          34
#         11          35
#         12          28
#         13          39
#         14          33
#         15          38
#         16          36
#         17          35
#         18          28
#         19          29
#         2           25
#         20          40
#         3           34
#         4           26
#         5           23
#         6           27
#         7           26
#         8           25
#         9           36
# Male    1           30
#         10          39
#         11          45
#         12          17
#         13          40
#         14          35
#         15          49
#         16          38
#         17          44
#         18          32
#         19          43
#         2           28
#         20          38
#         3           41
#         4           29
#         5           32
#         6           41
#         7           33
#         8           36
#         9           35
# Name: Transaction_ID, dtype: int64

# %%
# [42] Store_ID が [1, 5, 9] の取引を抽出し、Store_ID ごとに Quantity の合計を計算
filtered_data = sales_df.query("Store_ID in ['1', '5', '9']")
filtered_data.groupby("Store_ID")["Quantity"].sum()
# Out:
# Store_ID
# 1    111
# 5    125
# 9    112
# Name: Quantity, dtype: int64

# %%
# [43] データセットの最後の10日間の取引を抽出し、Transaction_Date ごとにAmountを集計
last_10_days = sales_df[sales_df["Transaction_Date"] > sales_df["Transaction_Date"].max() - pd.Timedelta(days=10)] #pd.Timedeltaを使えばデータ型で算術式が可能
last_10_days.groupby("Transaction_Date")["Amount"].sum()
# おまけ：sales_df['Transaction_Date'].dt.date #日付だけとりだすことができる
# Out:
# Transaction_Date
# 2024-08-21 02:35:00    6140
# 2024-08-21 05:31:00    1910
# 2024-08-21 08:27:00    4290
# 2024-08-21 11:23:00    9090
# 2024-08-21 14:19:00    9990
#                        ...
# 2024-08-30 12:16:00    8400
# 2024-08-30 15:12:00    3930
# 2024-08-30 18:08:00    2530
# 2024-08-30 21:04:00    4160
# 2024-08-31 00:00:00    7530
# Name: Amount, Length: 82, dtype: int64

# %%
# [44] 合計Amountが最も高い会員トップ5を特定
sales_df.groupby("Member_ID")["Amount"].sum().nlargest(5) #sort_valuesでもできる
# Out:
# Member_ID
# 49     55220
# 260    55130
# 154    51360
# 149    51250
# 158    50200
# Name: Amount, dtype: int64

# %% [markdown]
# ### 45から50本目agg関数と正規表現の使い方

# %%
# [45] 会員ごとに最も新しい取引を集計
sales_df.groupby("Member_ID")["Transaction_Date"].max()
# Out:
# Member_ID
# 1     2024-08-24 00:56:00
# 10    2024-06-26 04:13:00
# 100   2024-08-08 00:59:00
# 101   2024-07-27 16:24:00
# 102   2024-08-09 03:21:00
#               ...
# 95    2024-06-22 18:09:00
# 96    2024-05-28 23:10:00
# 97    2024-07-23 09:49:00
# 98    2024-07-19 03:14:00
# 99    2024-07-20 05:37:00
# Name: Transaction_Date, Length: 288, dtype: datetime64[ns]

# %%
# [46] 会員ごとに最も古い取引を集計
sales_df.groupby("Member_ID")["Transaction_Date"].min()
# Out:
# Member_ID
# 1     2024-08-04 20:46:00
# 10    2024-05-07 02:32:00
# 100   2024-05-08 19:34:00
# 101   2024-05-23 17:09:00
# 102   2024-05-13 10:57:00
#               ...
# 95    2024-05-27 06:09:00
# 96    2024-05-28 23:10:00
# 97    2024-06-01 09:14:00
# 98    2024-07-17 21:56:00
# 99    2024-05-31 12:43:00
# Name: Transaction_Date, Length: 288, dtype: datetime64[ns]

# %%
# [47] 会員ごとに取引日時の最も古いデータと最も新しいデータを集計し、それぞれが違うレコードを抽出
df_tmp = sales_df.groupby("Member_ID").agg({"Transaction_Date":["min","max"]}).reset_index()
df_tmp
df_tmp.columns = ["Member_ID", "Transaction_Date_Max", "Transaction_Date_Min"]
df_tmp.query("Transaction_Date_Max != Transaction_Date_Min")
# Out:
#     Member_ID Transaction_Date_Max Transaction_Date_Min
# 0           1  2024-08-04 20:46:00  2024-08-24 00:56:00
# 1          10  2024-05-07 02:32:00  2024-06-26 04:13:00
# 2         100  2024-05-08 19:34:00  2024-08-08 00:59:00
# 3         101  2024-05-23 17:09:00  2024-07-27 16:24:00
# 4         102  2024-05-13 10:57:00  2024-08-09 03:21:00
# ..        ...                  ...                  ...
# 282        93  2024-08-16 14:09:00  2024-08-29 15:45:00
# 283        95  2024-05-27 06:09:00  2024-06-22 18:09:00
# 285        97  2024-06-01 09:14:00  2024-07-23 09:49:00
# 286        98  2024-07-17 21:56:00  2024-07-19 03:14:00
# 287        99  2024-05-31 12:43:00  2024-07-20 05:37:00
#
# [252 rows x 3 columns]

# %%
# [48] Member_IDに[2]が含まれるか会員の取引を抽出
sales_df[sales_df["Member_ID"].str.contains("2")]
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 0                1 2024-05-01 00:00:00        21         25       12
# 3                4 2024-05-01 08:47:00       124         38        1
# 4                5 2024-05-01 11:43:00       281         28        5
# 5                6 2024-05-01 14:39:00       292         21       14
# 6                7 2024-05-01 17:35:00       203         43        5
# ..             ...                 ...       ...        ...      ...
# 994            995 2024-08-30 09:20:00       235          8       12
# 995            996 2024-08-30 12:16:00       213         33       15
# 996            997 2024-08-30 15:12:00        62         49       19
# 998            999 2024-08-30 21:04:00       127         11       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Amount
# 0           3    5820
# 3           3    5980
# 4           4    9390
# 5           4    8730
# 6           3    9830
# ..        ...     ...
# 994         1    7880
# 995         3    8400
# 996         3    3930
# 998         3    4160
# 999         2    7530
#
# [464 rows x 7 columns]

# %%
# [49] Product_ID が「1」で始まる取引を抽出
sales_df[sales_df["Product_ID"].str.contains("^1", regex=True)]
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 7                8 2024-05-01 20:30:00        51         18        1
# 21              22 2024-05-03 13:32:00       106         15       15
# 25              26 2024-05-04 01:16:00        77         11       18
# 38              39 2024-05-05 15:22:00       263          1        9
# 39              40 2024-05-05 18:18:00       172          1       17
# ..             ...                 ...       ...        ...      ...
# 991            992 2024-08-30 00:33:00       258         19       14
# 992            993 2024-08-30 03:29:00        81         18       13
# 993            994 2024-08-30 06:24:00       268         16        7
# 997            998 2024-08-30 18:08:00        49         12       11
# 998            999 2024-08-30 21:04:00       127         11       15
#
#      Quantity  Amount
# 7           4    5510
# 21          4    9360
# 25          2    3220
# 38          4    8630
# 39          2    6970
# ..        ...     ...
# 991         1    7220
# 992         3    7610
# 993         1    2370
# 997         4    2530
# 998         3    4160
#
# [223 rows x 7 columns]

# %%
# [50] Store_ID が「5」で終わる取引を抽出
sales_df[sales_df["Store_ID"].str.contains("5$", regex=True)]
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 4                5 2024-05-01 11:43:00       281         28        5
# 6                7 2024-05-01 17:35:00       203         43        5
# 12              13 2024-05-02 11:10:00       290         38        5
# 14              15 2024-05-02 17:01:00        27         44       15
# 21              22 2024-05-03 13:32:00       106         15       15
# ..             ...                 ...       ...        ...      ...
# 978            979 2024-08-28 10:27:00        51         31        5
# 981            982 2024-08-28 19:14:00        39         23       15
# 982            983 2024-08-28 22:10:00        28          2        5
# 995            996 2024-08-30 12:16:00       213         33       15
# 998            999 2024-08-30 21:04:00       127         11       15
#
#      Quantity  Amount
# 4           4    9390
# 6           3    9830
# 12          4    4960
# 14          1    3340
# 21          4    9360
# ..        ...     ...
# 978         3    4760
# 981         1    3230
# 982         2    2020
# 995         3    8400
# 998         3    4160
#
# [108 rows x 7 columns]

# %% [markdown]
# ### [51から54本目]正規表現の使い方

# %%
# [51] Transaction_ID が奇数の取引を抽出
sales_df[sales_df["Transaction_ID"].str.contains("[13579]$", regex=True)]
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 0                1 2024-05-01 00:00:00        21         25       12
# 2                3 2024-05-01 05:51:00       117         24        6
# 4                5 2024-05-01 11:43:00       281         28        5
# 6                7 2024-05-01 17:35:00       203         43        5
# 8                9 2024-05-01 23:26:00       271         36       18
# ..             ...                 ...       ...        ...      ...
# 990            991 2024-08-29 21:37:00       296         16       14
# 992            993 2024-08-30 03:29:00        81         18       13
# 994            995 2024-08-30 09:20:00       235          8       12
# 996            997 2024-08-30 15:12:00        62         49       19
# 998            999 2024-08-30 21:04:00       127         11       15
#
#      Quantity  Amount
# 0           3    5820
# 2           3    1270
# 4           4    9390
# 6           3    9830
# 8           2    7990
# ..        ...     ...
# 990         2    9350
# 992         3    7610
# 994         1    7880
# 996         3    3930
# 998         3    4160
#
# [500 rows x 7 columns]

# %%
# [52] ember_ID が3桁の会員の取引を抽出
sales_df[sales_df["Member_ID"].str.contains("^\d{3}$", regex=True)] #^\d{3}$で3桁
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 1                2 2024-05-01 02:55:00       107         23       17
# 2                3 2024-05-01 05:51:00       117         24        6
# 3                4 2024-05-01 08:47:00       124         38        1
# 4                5 2024-05-01 11:43:00       281         28        5
# 5                6 2024-05-01 14:39:00       292         21       14
# ..             ...                 ...       ...        ...      ...
# 993            994 2024-08-30 06:24:00       268         16        7
# 994            995 2024-08-30 09:20:00       235          8       12
# 995            996 2024-08-30 12:16:00       213         33       15
# 998            999 2024-08-30 21:04:00       127         11       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Amount
# 1           1     640
# 2           3    1270
# 3           3    5980
# 4           4    9390
# 5           4    8730
# ..        ...     ...
# 993         1    2370
# 994         1    7880
# 995         3    8400
# 998         3    4160
# 999         2    7530
#
# [687 rows x 7 columns]

# %%
# [53] Member_ID に「1」と「3」が連続して含まれる取引を抽出7
sales_df[sales_df["Member_ID"].str.contains("13")]
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 19              20 2024-05-03 07:41:00       136         28       20
# 26              27 2024-05-04 04:12:00       132         48       10
# 84              85 2024-05-11 06:11:00       138         30        2
# 112            113 2024-05-14 16:15:00       136         45       15
# 117            118 2024-05-15 06:55:00       130         34       11
# 130            131 2024-05-16 21:01:00       130         28       14
# 151            152 2024-05-19 10:34:00       136         17        3
# 198            199 2024-05-25 04:19:00       134          7       17
# 205            206 2024-05-26 00:50:00       130         17       20
# 238            239 2024-05-30 01:33:00       130         47       16
# 244            245 2024-05-30 19:08:00       130         49       14
# 279            280 2024-06-04 01:43:00       133          3        1
# 287            288 2024-06-05 01:10:00       138         38        1
# 289            290 2024-06-05 07:02:00        13          2        2
# 290            291 2024-06-05 09:58:00       213         40       19
# 292            293 2024-06-05 15:49:00       213         34        1
# 316            317 2024-06-08 14:10:00       113         13       16
# 322            323 2024-06-09 07:45:00       130         31       12
# 350            351 2024-06-12 17:49:00       133         18       13
# 355            356 2024-06-13 08:28:00       139         49       15
# 362            363 2024-06-14 04:59:00       138         32        8
# 367            368 2024-06-14 19:39:00       136         24       11
# 398            399 2024-06-18 14:30:00       213         29       10
# 402            403 2024-06-19 02:14:00       113         10        8
# 415            416 2024-06-20 16:20:00       135          4       18
# 429            430 2024-06-22 09:22:00       213         48        4
# 451            452 2024-06-25 01:50:00       136          9       16
# 465            466 2024-06-26 18:52:00        13          8       16
# 482            483 2024-06-28 20:42:00       132         13       16
# 484            485 2024-06-29 02:34:00       132         10        6
# 527            528 2024-07-04 08:36:00       113         34        9
# 531            532 2024-07-04 20:19:00       113         32        1
# 546            547 2024-07-06 16:17:00       137         32       16
# 549            550 2024-07-07 01:04:00       138         33       15
# 553            554 2024-07-07 12:48:00       113         45        6
# 583            584 2024-07-11 04:43:00       213         17        3
# 619            620 2024-07-15 14:14:00       131         11        8
# 656            657 2024-07-20 02:41:00       138         31       12
# 669            670 2024-07-21 16:47:00       213         25       18
# 723            724 2024-07-28 07:03:00       137         27       10
# 741            742 2024-07-30 11:49:00       131          7        8
# 745            746 2024-07-30 23:32:00       133         20        5
# 749            750 2024-07-31 11:16:00       134         49       18
# 752            753 2024-07-31 20:03:00       213         26       13
# 755            756 2024-08-01 04:51:00       131         18       18
# 773            774 2024-08-03 09:36:00       139          5        1
# 804            805 2024-08-07 04:28:00       134         45       19
# 888            889 2024-08-17 10:40:00       132         17       20
# 907            908 2024-08-19 18:21:00       136         24       18
# 919            920 2024-08-21 05:31:00       136         34       13
# 967            968 2024-08-27 02:12:00       113         40        6
# 995            996 2024-08-30 12:16:00       213         33       15
#
#      Quantity  Amount
# 19          1    7620
# 26          4    3290
# 84          3    1750
# 112         3    7880
# 117         1     650
# 130         3    5080
# 151         1    8150
# 198         1    8860
# 205         2    9030
# 238         3    2970
# 244         3    9920
# 279         4    8210
# 287         2    8160
# 289         3    4980
# 290         1    7250
# 292         1    1570
# 316         2    3180
# 322         4    3930
# 350         2    6450
# 355         2    5090
# 362         4    9900
# 367         4    1520
# 398         1    8760
# 402         3    5060
# 415         2    6760
# 429         1    3680
# 451         4    8200
# 465         2    3750
# 482         2    3620
# 484         2    7440
# 527         4    1710
# 531         4    4750
# 546         2    6070
# 549         4    7700
# 553         3    6580
# 583         1    1690
# 619         1    5250
# 656         4    9570
# 669         1     520
# 723         2    1550
# 741         2    8760
# 745         3    6820
# 749         1    3920
# 752         2    8900
# 755         3     960
# 773         3    4210
# 804         3    7000
# 888         3    9310
# 907         2     620
# 919         3    1910
# 967         4    6420
# 995         3    8400

# %%
# [54] Member_ID が「1」で始まり、任意の数字が続く会員の取引を抽出
sales_df[sales_df["Member_ID"].str.contains("^1\d*", regex=True)]
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 1                2 2024-05-01 02:55:00       107         23       17
# 2                3 2024-05-01 05:51:00       117         24        6
# 3                4 2024-05-01 08:47:00       124         38        1
# 10              11 2024-05-02 05:18:00       141         45        9
# 15              16 2024-05-02 19:57:00       157         34        7
# ..             ...                 ...       ...        ...      ...
# 979            980 2024-08-28 13:22:00       118          4       17
# 985            986 2024-08-29 06:58:00       155          8        6
# 986            987 2024-08-29 09:53:00       117          7       18
# 989            990 2024-08-29 18:41:00       166         50       17
# 998            999 2024-08-30 21:04:00       127         11       15
#
#      Quantity  Amount
# 1           1     640
# 2           3    1270
# 3           3    5980
# 10          4    6660
# 15          1    9280
# ..        ...     ...
# 979         2    1650
# 985         2    7470
# 986         2     790
# 989         2    5070
# 998         3    4160
#
# [397 rows x 7 columns]

# %% [markdown]
# ### [55から60本目]最頻値・中央値・分散・標準偏差

# %%
# [55] Product_IDごとの Quantityの最頻値を集計し、最頻値が3以上の商品を抽出
tmp_df =sales_df.groupby("Product_ID")["Quantity"].agg(lambda x: x.mode()[0]).reset_index()# lambda x: xに行いたい集計関数を与える
tmp_df.query("Quantity >= 3")
# Out:
#    Product_ID  Quantity
# 2          11         3
# 3          12         3
# 4          13         4
# 6          15         4
# 7          16         4
# 9          18         3
# 12         20         4
# 14         22         3
# 17         25         3
# 20         28         4
# 23         30         3
# 24         31         4
# 25         32         3
# 26         33         3
# 27         34         3
# 28         35         3
# 29         36         4
# 30         37         4
# 36         42         4
# 37         43         3
# 43         49         3
# 44          5         3
# 46          6         4

# %%
# [56] Product_IDごとのQuantityの最頻値を計算し、最頻値が最大の商品を抽出
tmp_df =sales_df.groupby("Product_ID")["Quantity"].agg(lambda x: x.mode()[0]).reset_index()# lambda x: xに行いたい集計関数を与える
tmp_df[tmp_df["Quantity"] == tmp_df["Quantity"].max()]
# Out:
#    Product_ID  Quantity
# 4          13         4
# 6          15         4
# 7          16         4
# 12         20         4
# 20         28         4
# 24         31         4
# 29         36         4
# 30         37         4
# 36         42         4
# 46          6         4

# %%
# [57] Store_ID ごとにAmountの分散を計算し、分散が大きい順にソート
sales_df.groupby("Store_ID")["Amount"].var().reset_index().sort_values(by="Amount", ascending=False)
# Out:
#    Store_ID        Amount
# 2        11  9.015945e+06
# 17        7  8.723997e+06
# 4        13  8.576469e+06
# 8        17  8.390790e+06
# 18        8  8.108668e+06
# 10       19  8.089241e+06
# 9        18  8.088676e+06
# 5        14  8.025426e+06
# 1        10  8.020134e+06
# 19        9  7.875109e+06
# 14        4  7.801350e+06
# 16        6  7.677862e+06
# 12       20  7.643865e+06
# 11        2  7.560622e+06
# 15        5  7.506359e+06
# 13        3  7.145211e+06
# 7        16  6.967726e+06
# 3        12  6.665951e+06
# 0         1  6.404298e+06
# 6        15  6.302731e+06

# %%
# [58] Member_ID ごとにAmountの標準偏差を計算し、標準偏差が4000以上の会員を抽出
tmp_df = sales_df.groupby("Member_ID")["Amount"].std().reset_index()
tmp_df.query("Amount >= 4000")
# Out:
#     Member_ID       Amount
# 9         107  4162.839576
# 17        114  4547.310560
# 20        117  4101.028326
# 24        120  4006.913817
# 32        129  4103.945662
# 90        181  4504.270196
# 94        186  4731.303555
# 104       198  4168.527918
# 113       206  4497.199128
# 116       209  4723.473298
# 128        22  4179.001077
# 133       224  5246.732316
# 137       228  4412.327428
# 145       235  5204.305910
# 156       245  6102.331522
# 157       246  5282.087655
# 161        25  4327.200789
# 200       286  4049.324018
# 204        29  4624.478349
# 207       292  4019.158287
# 212       297  5275.016588
# 258        71  5536.646097
# 263        76  4021.873941
# 281        92  4084.266560

# %%
# [59] 会員データにおいて年齢ごとに会員数を集計し、会員数が多い順にソート
member_df.groupby("Age")["Member_ID"].count().reset_index().sort_values(by="Member_ID", ascending=False)
# Out:
#     Age  Member_ID
# 62   80         12
# 12   30         11
# 53   71          9
# 23   41          8
# 31   49          8
# ..  ...        ...
# 37   55          2
# 21   39          1
# 35   53          1
# 60   78          1
# 5    23          1
#
# [63 rows x 2 columns]

# %%
# [60] 会員データの年齢の中央値を計算し、それより上の会員を抽出
age_median = member_df["Age"].median()
print("年齢の中央値:", age_median)
member_df.query("Age > @age_median")
member_df.query(f"Age > {age_median}")
# Out:
# 年齢の中央値: 50.0
#     Member_ID  Gender  Age  Days_Since_Registration Age_Group Year_Group
# 0          21    Male   69                      730       66-        2年-
# 2         117    Male   66                     1976       66-        2年-
# 4         281    Male   69                      269       66-         1年
# 5         292    Male   59                      454     51-65      1年-2年
# 6         203    Male   76                     1889       66-        2年-
# ..        ...     ...  ...                      ...       ...        ...
# 289        13  Female   79                      107       66-         1年
# 291       242  Female   54                      115     51-65         1年
# 294       173  Female   66                      393       66-      1年-2年
# 296       164  Female   58                     1613     51-65        2年-
# 297       188  Female   71                     1177       66-        2年-
#
# [148 rows x 6 columns]

# %% [markdown]
# ### [61から65本目]pivot_table,melt

# %%
# [61] Amountの大きいものから順番にランクを付与した上で昇順で並び替えてください。また同じAmountの場合は先に出現したものに高いランクを付与
df_tmp = pd.concat([sales_df[["Transaction_ID", "Amount"]],sales_df["Amount"].rank(method="first", ascending=False)], axis=1)
df_tmp.columns = ["Transaction", "Amount", "Ranking"]
df_tmp.sort_values(by="Ranking")
# Out:
#     Transaction  Amount  Ranking
# 199         200   10000      1.0
# 601         602   10000      2.0
# 816         817    9990      3.0
# 922         923    9990      4.0
# 179         180    9980      5.0
# ..          ...     ...      ...
# 442         443     530    996.0
# 423         424     520    997.0
# 650         651     520    998.0
# 669         670     520    999.0
# 841         842     510   1000.0
#
# [1000 rows x 3 columns]

# %%
# [62] Member_ID ごとの合計Amountに対して、パーセンタイル値を計算して低い順に並び替えてください
df_tmp = sales_df.groupby("Member_ID")["Amount"].sum().reset_index()
df_tmp = pd.concat([df_tmp[["Member_ID", "Amount"]], df_tmp[["Amount"]].rank(pct=True)], axis=1)
df_tmp.columns = ["Member_ID", "Amount", "Percentile"]
df_tmp.sort_values(by="Percentile")
# Out:
#     Member_ID  Amount  Percentile
# 280        91    1250    0.003472
# 50        145    1330    0.006944
# 169       257    1560    0.010417
# 196       282    1660    0.013889
# 120       212    1950    0.017361
# ..        ...     ...         ...
# 64        158   50200    0.986111
# 54        149   51250    0.989583
# 60        154   51360    0.993056
# 173       260   55130    0.996528
# 235        49   55220    1.000000
#
# [288 rows x 3 columns]

# %%
# [63] 年代を縦（行）、性別を横（列）に持つテーブルで、各セグメントごとの平均取引金額を集計
pivot_table = merged_df.pivot_table(index="Age_Group", columns="Gender", values="Amount", aggfunc="mean")
pivot_table
# Out:
# <ipython-input-72-199d61e4a1ca>:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_table = merged_df.pivot_table(index="Age_Group", columns="Gender", values="Amount", aggfunc="mean")
# Gender          Female         Male
# Age_Group
# -30        5227.769784  5332.400000
# 31-50      5316.318182  5040.873362
# 51-65      5619.541985  5471.677419
# 66-        5035.984848  5459.548872

# %%
# [64] 前の課題のテーブルを、年代と性別が縦に並ぶように変換
# pivot_table.reset_index() #まずはAge_Groupを取り出す
pivot_table.reset_index().melt(id_vars="Age_Group", var_name="Gender", value_name="Average_Amount")
# Out:
#   Age_Group  Gender  Average_Amount
# 0       -30  Female     5227.769784
# 1     31-50  Female     5316.318182
# 2     51-65  Female     5619.541985
# 3       66-  Female     5035.984848
# 4       -30    Male     5332.400000
# 5     31-50    Male     5040.873362
# 6     51-65    Male     5471.677419
# 7       66-    Male     5459.548872

# %%
# [65] 年代✕性別のごとの取引回数を集計し表示
merged_df.pivot_table(index="Age_Group", columns="Gender", values="Transaction_ID", aggfunc="count")
# Out:
# <ipython-input-74-b5f063d07d08>:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   merged_df.pivot_table(index="Age_Group", columns="Gender", values="Transaction_ID", aggfunc="count")
# Gender     Female  Male
# Age_Group
# -30           139    75
# 31-50         220   229
# 51-65         131   155
# 66-           132   266

# %% [markdown]
# ### [65から67本目]フラグの作成方法

# %%
# [66] Amount が2000円以上なら 1、それ未満なら 0 を割り振ったフラグを新しいカラムに追加
sales_df["Amount_Flag"] = (sales_df["Amount"] >= 2000).astype(int)
sales_df
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 0                1 2024-05-01 00:00:00        21         25       12
# 1                2 2024-05-01 02:55:00       107         23       17
# 2                3 2024-05-01 05:51:00       117         24        6
# 3                4 2024-05-01 08:47:00       124         38        1
# 4                5 2024-05-01 11:43:00       281         28        5
# ..             ...                 ...       ...        ...      ...
# 995            996 2024-08-30 12:16:00       213         33       15
# 996            997 2024-08-30 15:12:00        62         49       19
# 997            998 2024-08-30 18:08:00        49         12       11
# 998            999 2024-08-30 21:04:00       127         11       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Amount  Amount_Flag
# 0           3    5820            1
# 1           1     640            0
# 2           3    1270            0
# 3           3    5980            1
# 4           4    9390            1
# ..        ...     ...          ...
# 995         3    8400            1
# 996         3    3930            1
# 997         4    2530            1
# 998         3    4160            1
# 999         2    7530            1
#
# [1000 rows x 8 columns]

# %%
# [67] Quantity の平均値以上の取引に 1、それ未満に 0 のフラグを追加
mean_quantity = sales_df["Quantity"].mean()
sales_df["Quantity_Flag"] = (sales_df["Quantity"] >= 2000).astype(int)
sales_df
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 0                1 2024-05-01 00:00:00        21         25       12
# 1                2 2024-05-01 02:55:00       107         23       17
# 2                3 2024-05-01 05:51:00       117         24        6
# 3                4 2024-05-01 08:47:00       124         38        1
# 4                5 2024-05-01 11:43:00       281         28        5
# ..             ...                 ...       ...        ...      ...
# 995            996 2024-08-30 12:16:00       213         33       15
# 996            997 2024-08-30 15:12:00        62         49       19
# 997            998 2024-08-30 18:08:00        49         12       11
# 998            999 2024-08-30 21:04:00       127         11       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Amount  Amount_Flag  Quantity_Flag
# 0           3    5820            1              0
# 1           1     640            0              0
# 2           3    1270            0              0
# 3           3    5980            1              0
# 4           4    9390            1              0
# ..        ...     ...          ...            ...
# 995         3    8400            1              0
# 996         3    3930            1              0
# 997         4    2530            1              0
# 998         3    4160            1              0
# 999         2    7530            1              0
#
# [1000 rows x 9 columns]

# %% [markdown]
# ### [68から70本目]カテゴリ変数とダミー変数化

# %%
# [68]　の補足
member_sales = sales_df.groupby("Member_ID")["Amount"].sum()
member_sales.reset_index()["Amount"].max() #100%のカテゴリのために最大値取得
# Out:
# 55220

# %%
# [68] 顧客ごとの合計Amountに基づいて、〜25%点、〜50%点、〜75%点、〜100%点ごとに4つのカテゴリに分け、そのカテゴリを新しいカラムとして追加
member_sales = sales_df.groupby("Member_ID")["Amount"].sum()
q1,q2,q3 = member_sales.quantile([0.25,0.5,0.75])
category_labels = [1,2,3,4]
category_bins = [0, q1, q2, q3, member_sales.reset_index()["Amount"].max()]
sales_df = sales_df.merge(member_sales.rename("Total_Sales"), on = "Member_ID")
sales_df["Sales_Category"] = pd.cut(sales_df["Total_Sales"], bins=category_bins, labels=category_labels)
sales_df
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 0                1 2024-05-01 00:00:00        21         25       12
# 1                2 2024-05-01 02:55:00       107         23       17
# 2                3 2024-05-01 05:51:00       117         24        6
# 3                4 2024-05-01 08:47:00       124         38        1
# 4                5 2024-05-01 11:43:00       281         28        5
# ..             ...                 ...       ...        ...      ...
# 995            996 2024-08-30 12:16:00       213         33       15
# 996            997 2024-08-30 15:12:00        62         49       19
# 997            998 2024-08-30 18:08:00        49         12       11
# 998            999 2024-08-30 21:04:00       127         11       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Amount  Amount_Flag  Quantity_Flag  Total_Sales Sales_Category
# 0           3    5820            1              0        28200              4
# 1           1     640            0              0        26420              4
# 2           3    1270            0              0        32130              4
# 3           3    5980            1              0        31240              4
# 4           4    9390            1              0        26070              4
# ..        ...     ...          ...            ...          ...            ...
# 995         3    8400            1              0        40770              4
# 996         3    3930            1              0        11360              2
# 997         4    2530            1              0        55220              4
# 998         3    4160            1              0        36600              4
# 999         2    7530            1              0        22890              3
#
# [1000 rows x 11 columns]

# %%
# [69] Quantityが小さい順に等しく3つのカテゴリに分け、そのカテゴリを新しいカラムに追加
quantity_labels = ["Low", "Medium", "High"]
sales_df["Quantity_Category"] = pd.qcut(sales_df["Quantity"], q=3, labels=quantity_labels)
sales_df
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 0                1 2024-05-01 00:00:00        21         25       12
# 1                2 2024-05-01 02:55:00       107         23       17
# 2                3 2024-05-01 05:51:00       117         24        6
# 3                4 2024-05-01 08:47:00       124         38        1
# 4                5 2024-05-01 11:43:00       281         28        5
# ..             ...                 ...       ...        ...      ...
# 995            996 2024-08-30 12:16:00       213         33       15
# 996            997 2024-08-30 15:12:00        62         49       19
# 997            998 2024-08-30 18:08:00        49         12       11
# 998            999 2024-08-30 21:04:00       127         11       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Amount  Amount_Flag  Quantity_Flag  Total_Sales Sales_Category  \
# 0           3    5820            1              0        28200              4
# 1           1     640            0              0        26420              4
# 2           3    1270            0              0        32130              4
# 3           3    5980            1              0        31240              4
# 4           4    9390            1              0        26070              4
# ..        ...     ...          ...            ...          ...            ...
# 995         3    8400            1              0        40770              4
# 996         3    3930            1              0        11360              2
# 997         4    2530            1              0        55220              4
# 998         3    4160            1              0        36600              4
# 999         2    7530            1              0        22890              3
#
#     Quantity_Category
# 0              Medium
# 1                 Low
# 2              Medium
# 3              Medium
# 4                High
# ..                ...
# 995            Medium
# 996            Medium
# 997              High
# 998            Medium
# 999               Low
#
# [1000 rows x 12 columns]

# %%
# [70] Gender カラムをダミー変数化
gender_dumies = pd.get_dummies(member_df["Gender"])
# gender_dumies
member_df = pd.concat([member_df, gender_dumies], axis=1)
member_df
# Out:
#     Member_ID  Gender  Age  Days_Since_Registration Age_Group Year_Group  \
# 0          21    Male   69                      730       66-        2年-
# 1         107  Female   18                      958       -30        2年-
# 2         117    Male   66                     1976       66-        2年-
# 3         124  Female   49                     1881     31-50        2年-
# 4         281    Male   69                      269       66-         1年
# ..        ...     ...  ...                      ...       ...        ...
# 295       160    Male   41                     1513     31-50        2年-
# 296       164  Female   58                     1613     51-65        2年-
# 297       188  Female   71                     1177       66-        2年-
# 298       191  Female   38                     1660     31-50        2年-
# 299       256  Female   50                      104     31-50         1年
#
#      Female   Male
# 0     False   True
# 1      True  False
# 2     False   True
# 3      True  False
# 4     False   True
# ..      ...    ...
# 295   False   True
# 296    True  False
# 297    True  False
# 298    True  False
# 299    True  False
#
# [300 rows x 8 columns]

# %% [markdown]
# ### [71から74本目]標準化とサンプリング

# %%
# [71]　Amount カラムを標準化して新しいカラムを追加
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
sales_df["Amount_Standard"] = scaler.fit_transform(sales_df[["Amount"]])
sales_df
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 0                1 2024-05-01 00:00:00        21         25       12
# 1                2 2024-05-01 02:55:00       107         23       17
# 2                3 2024-05-01 05:51:00       117         24        6
# 3                4 2024-05-01 08:47:00       124         38        1
# 4                5 2024-05-01 11:43:00       281         28        5
# ..             ...                 ...       ...        ...      ...
# 995            996 2024-08-30 12:16:00       213         33       15
# 996            997 2024-08-30 15:12:00        62         49       19
# 997            998 2024-08-30 18:08:00        49         12       11
# 998            999 2024-08-30 21:04:00       127         11       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Amount  Amount_Flag  Quantity_Flag  Total_Sales Sales_Category  \
# 0           3    5820            1              0        28200              4
# 1           1     640            0              0        26420              4
# 2           3    1270            0              0        32130              4
# 3           3    5980            1              0        31240              4
# 4           4    9390            1              0        26070              4
# ..        ...     ...          ...            ...          ...            ...
# 995         3    8400            1              0        40770              4
# 996         3    3930            1              0        11360              2
# 997         4    2530            1              0        55220              4
# 998         3    4160            1              0        36600              4
# 999         2    7530            1              0        22890              3
#
#     Quantity_Category  Amount_Standard
# 0              Medium         0.173344
# 1                 Low        -1.692082
# 2              Medium        -1.465206
# 3              Medium         0.230964
# 4                High         1.458976
# ..                ...              ...
# 995            Medium         1.102456
# 996            Medium        -0.507284
# 997              High        -1.011454
# 998            Medium        -0.424457
# 999               Low         0.789151
#
# [1000 rows x 13 columns]

# %%
# [72] 取引データ全体のうち10%をランダムにサンプリング
sales_df.sample(frac=0.1)
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 701            702 2024-07-25 14:34:00        47         24        3
# 791            792 2024-08-05 14:21:00       294         47       10
# 703            704 2024-07-25 20:26:00       104         22        2
# 880            881 2024-08-16 11:13:00        26         49       20
# 509            510 2024-07-02 03:50:00        24         25        5
# ..             ...                 ...       ...        ...      ...
# 291            292 2024-06-05 12:54:00       242         17       13
# 736            737 2024-07-29 21:09:00        59         34        8
# 156            157 2024-05-20 01:13:00       279         34        8
# 832            833 2024-08-10 14:32:00       251          4       17
# 215            216 2024-05-27 06:09:00        95         13       13
#
#      Quantity  Amount  Amount_Flag  Quantity_Flag  Total_Sales Sales_Category  \
# 701         2    7560            1              0        30710              4
# 791         2    9710            1              0        17550              3
# 703         3    7710            1              0        19490              3
# 880         4    8930            1              0        22510              3
# 509         4    5060            1              0        12060              2
# ..        ...     ...          ...            ...          ...            ...
# 291         2    4670            1              0        13350              2
# 736         3    3230            1              0        11690              2
# 156         1    6290            1              0        21680              3
# 832         1    1880            0              0        22500              3
# 215         1     840            0              0         2620              1
#
#     Quantity_Category  Amount_Standard
# 701               Low         0.799955
# 791               Low         1.574215
# 703            Medium         0.853973
# 880              High         1.293320
# 509              High        -0.100348
# ..                ...              ...
# 291               Low        -0.240795
# 736            Medium        -0.759369
# 156               Low         0.342601
# 832               Low        -1.245532
# 215               Low        -1.620058
#
# [100 rows x 13 columns]

# %%
# [73] 会員データの20%をランダムにサンプリング
sales_df.sample(frac=0.2)
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 926            927 2024-08-22 02:02:00       233         20        2
# 562            563 2024-07-08 15:10:00        74         34        4
# 406            407 2024-06-19 13:57:00       119         21        2
# 630            631 2024-07-16 22:29:00        61          6        4
# 705            706 2024-07-26 02:18:00        42         22        6
# ..             ...                 ...       ...        ...      ...
# 476            477 2024-06-28 03:07:00       243         40       17
# 960            961 2024-08-26 05:41:00       146         40       13
# 350            351 2024-06-12 17:49:00       133         18       13
# 829            830 2024-08-10 05:44:00       206         24        4
# 973            974 2024-08-27 19:47:00       285         16       15
#
#      Quantity  Amount  Amount_Flag  Quantity_Flag  Total_Sales Sales_Category  \
# 926         4    7020            1              0        11340              2
# 562         2    2250            1              0        16640              2
# 406         1    1370            0              0        14070              2
# 630         4    4970            1              0        34230              4
# 705         4    6570            1              0        30480              4
# ..        ...     ...          ...            ...          ...            ...
# 476         1    4710            1              0         9320              1
# 960         4    9060            1              0        34350              4
# 350         2    6450            1              0        21480              3
# 829         2    8080            1              0         9800              1
# 973         3    8160            1              0        11890              2
#
#     Quantity_Category  Amount_Standard
# 926              High         0.605489
# 562               Low        -1.112287
# 406               Low        -1.429194
# 630              High        -0.132759
# 705              High         0.443435
# ..                ...              ...
# 476               Low        -0.226390
# 960              High         1.340136
# 350               Low         0.400220
# 829               Low         0.987217
# 973            Medium         1.016027
#
# [200 rows x 13 columns]

# %%
# [74] Amount が5000円以上の取引からランダムに5件をサンプリング
sales_df[sales_df["Amount"] >= 5000].sample(n=5)
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 924            925 2024-08-21 20:10:00       192          6        9
# 762            763 2024-08-02 01:22:00       190          1       20
# 269            270 2024-06-02 20:25:00       116         34       11
# 781            782 2024-08-04 09:03:00        47          4       12
# 313            314 2024-06-08 05:22:00        42         17        3
#
#      Quantity  Amount  Amount_Flag  Quantity_Flag  Total_Sales Sales_Category  \
# 924         4    8880            1              0        26780              4
# 762         4    5150            1              0        27250              4
# 269         4    7880            1              0        34020              4
# 781         2    6790            1              0        30710              4
# 313         1    7300            1              0        30480              4
#
#     Quantity_Category  Amount_Standard
# 924              High         1.275314
# 762              High        -0.067937
# 269              High         0.915193
# 781               Low         0.522662
# 313               Low         0.706323

# %% [markdown]
# ### [75から77本目]層化抽出・外れ値・CSV出力

# %%
# [75] Gender を層化基準にして取引データから20%抽出
from sklearn.model_selection import train_test_split #最初に学習データ、テストデータとして分ける
_, temp_df = train_test_split(merged_df,test_size=0.2,stratify=merged_df["Gender"]) #maleとfemaleの割合を保ったまま抽出(80％が学習データ、20%がテストデータ)
temp_df #学習データは使わないため_としてる。
# Out:
#      Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 133              69 2024-05-09 07:18:00       146          5       10
# 774             422 2024-06-21 09:55:00        86         20       15
# 65               35 2024-05-05 03:39:00       241         37        9
# 827             475 2024-06-27 21:15:00        20         21       16
# 1014            666 2024-07-21 05:04:00        68         26       17
# ...             ...                 ...       ...        ...      ...
# 388             183 2024-05-23 05:25:00       154         11       13
# 1072            716 2024-07-27 07:36:00       101         43        5
# 752             401 2024-06-18 20:22:00       288         27       11
# 939             585 2024-07-11 07:39:00       106         26       19
# 1246            889 2024-08-17 10:40:00       132         17       20
#
#       Quantity  Amount  Gender  Age  Days_Since_Registration Age_Group  \
# 133          4    2250    Male   56                     1070     51-65
# 774          4    8750    Male   34                      849     31-50
# 65           4    6230  Female   79                     1965       66-
# 827          4    3580    Male   67                      351       66-
# 1014         3    4480  Female   54                     1879     51-65
# ...        ...     ...     ...  ...                      ...       ...
# 388          1    5850    Male   80                     1961       66-
# 1072         3    9120    Male   77                      315       66-
# 752          3    6940    Male   31                      498     31-50
# 939          3     750    Male   80                      527       66-
# 1246         3    9310    Male   27                      440       -30
#
#      Year_Group
# 133         2年-
# 774         2年-
# 65          2年-
# 827          1年
# 1014        2年-
# ...         ...
# 388         2年-
# 1072         1年
# 752       1年-2年
# 939       1年-2年
# 1246      1年-2年
#
# [270 rows x 12 columns]

# %%
# [76] Amount の平均から1σ以上離れた取引を外れ値として抽出(本来は3σ)
amount_mean = sales_df["Amount"].mean()
amount_std = sales_df["Amount"].std() #1σ
print(amount_mean + amount_std)
print(amount_mean - amount_std)
# 1σ高いor1σ低い範囲を取得する式を書く
sales_df[(sales_df["Amount"] > amount_mean + amount_std) | (sales_df["Amount"] < amount_mean - amount_std )]
# Out:
# 8116.884486929517
# 2560.4155130704817
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 1                2 2024-05-01 02:55:00       107         23       17
# 2                3 2024-05-01 05:51:00       117         24        6
# 4                5 2024-05-01 11:43:00       281         28        5
# 5                6 2024-05-01 14:39:00       292         21       14
# 6                7 2024-05-01 17:35:00       203         43        5
# ..             ...                 ...       ...        ...      ...
# 986            987 2024-08-29 09:53:00       117          7       18
# 990            991 2024-08-29 21:37:00       296         16       14
# 993            994 2024-08-30 06:24:00       268         16        7
# 995            996 2024-08-30 12:16:00       213         33       15
# 997            998 2024-08-30 18:08:00        49         12       11
#
#      Quantity  Amount  Amount_Flag  Quantity_Flag  Total_Sales Sales_Category  \
# 1           1     640            0              0        26420              4
# 2           3    1270            0              0        32130              4
# 4           4    9390            1              0        26070              4
# 5           4    8730            1              0        13120              2
# 6           3    9830            1              0        31990              4
# ..        ...     ...          ...            ...          ...            ...
# 986         2     790            0              0        32130              4
# 990         2    9350            1              0         9350              1
# 993         1    2370            1              0        37370              4
# 995         3    8400            1              0        40770              4
# 997         4    2530            1              0        55220              4
#
#     Quantity_Category  Amount_Standard
# 1                 Low        -1.692082
# 2              Medium        -1.465206
# 4                High         1.458976
# 5                High         1.221296
# 6              Medium         1.617429
# ..                ...              ...
# 986               Low        -1.638064
# 990               Low         1.444571
# 993               Low        -1.069073
# 995            Medium         1.102456
# 997              High        -1.011454
#
# [422 rows x 13 columns]

# %%
# [77] 現在のmember_dfをCSVファイルとして出力
member_df.to_csv("New_Data.csv")

# %% [markdown]
# ###

# %%
# [78] seaborn を使って、merged_dfの数値カラム間の相関行列をヒートマップで可視化
import seaborn as sns
import matplotlib.pyplot as plt

numeric_sales_df = merged_df.select_dtypes(include = "number") #数字カラムだけを取得する
correlation_matrix = numeric_sales_df.corr() #相関係数
sns.heatmap(correlation_matrix,annot=True,cmap="coolwarm") #赤が正の相関が強い
# Out:
# <Axes: >

# %%
# [79] plotlyを使って、merged_dfの数値カラム間の相関行列をヒートマップで可視化
import plotly.express as px
fig = px.imshow(correlation_matrix, text_auto=True, color_continuous_scale="RdBu_r")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bbaafd50-c50b-4d13-850d-032a3cd2870e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbaafd50-c50b-4d13-850d-032a3cd2870e")) {                    Plotly.newPlot(                        "bbaafd50-c50b-4d13-850d-032a3cd2870e",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["Quantity","Amount","Age","Days_Since_Registration"],"y":["Quantity","Amount","Age","Days_Since_Registration"],"z":[[1.0,-0.00725241116111015,0.029611581190128883,-0.017064582173717785],[-0.00725241116111015,1.0,0.01805982478405931,-0.021375904657659733],[0.029611581190128883,0.01805982478405931,1.0,0.010818479738421956],[-0.017064582173717785,-0.021375904657659733,0.010818479738421956,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f ...

# %%
# [80] matplotlib を使って、月ごとの合計Amountを棒グラフで表示
monthly_sales = sales_df.groupby(sales_df["Transaction_Date"].dt.to_period("M"))["Amount"].sum().reset_index()
plt.bar(monthly_sales["Transaction_Date"].astype(str), monthly_sales["Amount"])
plt.xticks(rotation=45)
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.title("Monthly Sales")
plt.show()
